# %% [markdown]
# #Import Dependencies

# %%
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# #Load and Explore Dataset

# %%
#Since the Cifar10 dataset is available in keras, we'll load it from there
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

#Number of classes in the dataset
num_classes = 10

#Shape of the images
shape=(32,32,3)

#Cifar10 Classes
classes = {0:'Airplane', 1:'Automobile', 2:'Bird', 3:'Cat', 4:'Deer', 5:'Dog', 6:'Frog', 7:'Horse', 8:'Ship', 9:'Truck'}

#Displaying some random images from the dataset
Rows, Cols= 4, 8

#Create empty figure grid
fig = plt.figure(figsize=(2 * Cols - 1, 2.5 * Rows - 1))

#Iterate over the created grid
for i in range(Cols):
  for j in range(Rows):
    #Pick random index
    ind = random.randint(0, len(y_train))
    ax = fig.add_subplot(Rows, Cols, i * Rows + j + 1)
    ax.axis('off')
    #Display the image and corresponding class
    ax.imshow(x_train[ind, :])
    plt.title(classes[y_train[ind][0]])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# 170508288/170498071 [==============================] - 13s 0us/step

# %% [markdown]
# #Data Preprocessing

# %%
#Enocde the labels using one hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

#Convert the pixels values to floats for better calculations
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#Data Augmentation using data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    shear_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
    )

#Test dataset generator
test_datagen = ImageDataGenerator(rescale=1./255)

#Batch size
batch_size = 64

#Load training dataset to the generator
train_generator = train_datagen.flow(x_train, y_train,
                                     batch_size=batch_size)

#Load testing dataset to the generator
validation_generator = test_datagen.flow(x_test, y_test,
                                         batch_size=batch_size)

# %% [markdown]
# #Base Model

# %%
#Constructing the base model using keras
base_model = tf.keras.models.Sequential(
    #First convolutional layer
    [tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=shape),
     tf.keras.layers.MaxPooling2D(2,2),
     #Second convolutional layer
     tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2), 
     #Dropout layer to prevent overfitting
     tf.keras.layers.Dropout(0.3),
     #Flattening before fully connected layer
     tf.keras.layers.Flatten(), 
     #Fully connected layer
     tf.keras.layers.Dense(128, activation='relu'), 
     tf.keras.layers.Dropout(0.3),
     #Classification layer
     tf.keras.layers.Dense(num_classes, activation='softmax')  
     ])

#Print model summary
base_model.summary()

# %%
#Number of iterations to train the model
epochs = 60

#Model compilation
base_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

#Model training
history = base_model.fit(train_generator,
                         epochs=epochs,
                         validation_data=validation_generator,
                         batch_size = batch_size,
                         steps_per_epoch = len(x_train) // batch_size,
                         verbose=2)

# %%
#Plot training and validation loss
plt.figure(figsize=(10,5), dpi = 80)
#Epoch range
Epochs_range = np.linspace(1, epochs, epochs)
plt.plot(Epochs_range, history.history['loss'])
plt.plot(Epochs_range, history.history['val_loss'])
plt.grid()
#Label the figures
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend(['Training', 'Validation'])

#Plot training and validation accuracy
plt.figure(figsize=(10,5), dpi = 80)
plt.plot(Epochs_range, history.history['accuracy'])
plt.plot(Epochs_range, history.history['val_accuracy'])
plt.grid()
#Label the figures
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.legend(['Training', 'Validation'])

# %% [markdown]
# #Optimized Model

# %%
#Create the regulizers object
regularizer = regularizers.l2(1e-4)

#Construct model using keras
opt_model = tf.keras.models.Sequential([
    #First convolutional layer
    tf.keras.layers.Conv2D(128, (3,3), activation= 'relu', kernel_regularizer=regularizer, input_shape=shape, padding='same'),
    tf.keras.layers.MaxPooling2D(2,2),
    #Dropout 
    tf.keras.layers.Dropout(0.3),
    #2nd, 3rd, 4th and 5th convolutional layer
    tf.keras.layers.Conv2D(256, (3,3), activation= 'relu', kernel_regularizer=regularizer, padding='same'),
    tf.keras.layers.Conv2D(512, (3,3), activation= 'relu', kernel_regularizer=regularizer, padding='same'),
    tf.keras.layers.Conv2D(512, (3,3), activation= 'relu', kernel_regularizer=regularizer, padding='same'),
    tf.keras.layers.Conv2D(256, (3,3), activation= 'relu', kernel_regularizer=regularizer, padding='same'),
    tf.keras.layers.Dropout(0.3),
    #Flatten the output from convolutional block
    tf.keras.layers.Flatten(), 
    #1st, 2nd and 3rd fully connected layers
    tf.keras.layers.Dense(512, activation= 'relu'), 
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation= 'relu'), 
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation= 'relu'), 
    tf.keras.layers.Dropout(0.5),
    #Classification layer
    tf.keras.layers.Dense(num_classes, activation='softmax')  
])

#Print model summary
opt_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       3584
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 512)       1180160
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 512)       2359808
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)       1179904
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_2 (Dense)             (None, 512)               33554944
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 38,739,082
# Trainable params: 38,739,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Set learning rate for the optimizer
lr = 3e-4

#Set weight decay
weight_decay = 1e-6

#Model compilation
opt_model.compile(optimizer=Adam(learning_rate=lr, decay=weight_decay),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

#Model training
history = opt_model.fit(train_generator,
                        epochs=epochs,
                        validation_data=validation_generator,
                        batch_size = batch_size,
                        steps_per_epoch = len(x_train) // batch_size,
                        verbose=2)

#Save trained model
opt_model.save('Trained_Model.h5')
# Out:
# Epoch 1/60
# 781/781 - 50s - loss: 2.1402 - accuracy: 0.1930 - val_loss: 1.7179 - val_accuracy: 0.3639 - 50s/epoch - 64ms/step
# Epoch 2/60
# 781/781 - 47s - loss: 1.6706 - accuracy: 0.3807 - val_loss: 1.4039 - val_accuracy: 0.4781 - 47s/epoch - 60ms/step
# Epoch 3/60
# 781/781 - 48s - loss: 1.4615 - accuracy: 0.4743 - val_loss: 1.2672 - val_accuracy: 0.5394 - 48s/epoch - 61ms/step
# Epoch 4/60
# 781/781 - 47s - loss: 1.3432 - accuracy: 0.5254 - val_loss: 1.1588 - val_accuracy: 0.5904 - 47s/epoch - 61ms/step
# Epoch 5/60
# 781/781 - 48s - loss: 1.2646 - accuracy: 0.5580 - val_loss: 1.0821 - val_accuracy: 0.6242 - 48s/epoch - 61ms/step
# Epoch 6/60
# 781/781 - 47s - loss: 1.2096 - accuracy: 0.5838 - val_loss: 1.0664 - val_accuracy: 0.6332 - 47s/epoch - 61ms/step
# Epoch 7/60
# 781/781 - 47s - loss: 1.1473 - accuracy: 0.6074 - val_loss: 1.0247 - val_accuracy: 0.6559 - 47s/epoch - 60ms/step
# Epoch 8/60
# 781/781 - 47s - loss: 1.0973 - accuracy: 0.6294 - val_loss: 1.0040 - val_accuracy: 0.6558 - 47s/epoch - 61ms/step
# Epoch 9/60
# 781/781 - 47s - loss: 1.0663 - accuracy: 0.6418 - val_loss: 0.9918 - val_accuracy: 0.6660 - 47s/epoch - 60ms/step
# Epoch 10/60
# 781/781 - 48s - loss: 1.0292 - accuracy: 0.6584 - val_loss: 0.9875 - val_accuracy: 0.6639 - 48s/epoch - 61ms/step
# Epoch 11/60
# 781/781 - 47s - loss: 0.9949 - accuracy: 0.6704 - val_loss: 0.8636 - val_accuracy: 0.7110 - 47s/epoch - 61ms/step
# Epoch 12/60
# 781/781 - 47s - loss: 0.9646 - accuracy: 0.6823 - val_loss: 0.8836 - val_accuracy: 0.7063 - 47s/epoch - 60ms/step
# Epoch 13/60
# 781/781 - 47s - loss: 0.9378 - accuracy: 0.6920 - val_loss: 0.8438 - val_accuracy: 0.7220 - 47s/epoch - 60ms/step
# Epoch 14/60
# 781/781 - 47s - loss: 0.9051 - accuracy: 0.7038 - val_loss: 0.8049 - val_accuracy: 0.7334 - 47s/epoch - 61ms/step
# Epoch 15/60
# 781/781 - 48s - loss: 0.8832 - accuracy: 0.7129 - val_loss: 0.8418 - val_accuracy: 0.7303 - 48s/epoch - 61ms/step
# Epoch 16/60
# 781/781 - 47s - loss: 0.8683 - accuracy: 0.7196 - val_loss: 0.8120 - val_accuracy: 0.7310 - 47s/epoch - 61ms/step
# Epoch 17/60
# 781/781 - 47s - loss: 0.8488 - accuracy: 0.7283 - val_loss: 0.7622 - val_accuracy: 0.7527 - 47s/epoch - 61ms/step
# Epoch 18/60
# 781/781 - 47s - loss: 0.8342 - accuracy: 0.7319 - val_loss: 0.7227 - val_accuracy: 0.7661 - 47s/epoch - 61ms/step
# Epoch 19/60
# 781/781 - 47s - loss: 0.8088 - accuracy: 0.7421 - val_loss: 0.7188 - val_accuracy: 0.7681 - 47s/epoch - 61ms/step
# Epoch 20/60
# 781/781 - 47s - loss: 0.7938 - accuracy: 0.7468 - val_loss: 0.7200 - val_accuracy: 0.7715 - 47s/epoch - 60ms/step
# Epoch 21/60
# 781/781 - 47s - loss: 0.7780 - accuracy: 0.7522 - val_loss: 0.7108 - val_accuracy: 0.7735 - 47s/epoch - 60ms/step
# Epoch 22/60
# 781/781 - 47s - loss: 0.7655 - accuracy: 0.7578 - val_loss: 0.7591 - val_accuracy: 0.7583 - 47s/epoch - 61ms/step
# Epoch 23/60
# 781/781 - 47s - loss: 0.7599 - accuracy: 0.7611 - val_loss: 0.7356 - val_accuracy: 0.7707 - 47s/epoch - 60ms/step
# Epoch 24/60
# 781/781 - 47s - loss: 0.7430 - accuracy: 0.7650 - val_loss: 0.6777 - val_accuracy: 0.7844 - 47s/epoch - 61ms/step
# Epoch 25/60
# 781/781 - 47s - loss: 0.7350 - accuracy: 0.7701 - val_loss: 0.7848 - val_accuracy: 0.7549 - 47s/epoch - 61ms/step
# Epoch 26/60
# 781/781 - 47s - loss: 0.7246 - accuracy: 0.7720 - val_loss: 0.6924 - val_accuracy: 0.7817 - 47s/epoch - 61ms/step
# Epoch 27/60
# 781/781 - 47s - loss: 0.7124 - accuracy: 0.7777 - val_loss: 0.6975 - val_accuracy: 0.7807 - 47s/epoch - 60ms/step
# Epoch 28/60
# 781/781 - 48s - loss: 0.7063 - accuracy: 0.7827 - val_loss: 0.6578 - val_accuracy: 0.7994 - 48s/epoch - 61ms/step
# Epoch 29/60
# 781/781 - 47s - loss: 0.6926 - accuracy: 0.7866 - val_loss: 0.6515 - val_accuracy: 0.7990 - 47s/epoch - 60ms/step
# Epoch 30/60
# 781/781 - 48s - loss: 0.6877 - accuracy: 0.7898 - val_loss: 0.6262 - val_accuracy: 0.8052 - 48s/epoch - 61ms/step
# Epoch 31/60
# 781/781 - 47s - loss: 0.6781 - accuracy: 0.7913 - val_loss: 0.6406 - val_accuracy: 0.8022 - 47s/epoch - 60ms/step
# Epoch 32/60
# 781/781 - 48s - loss: 0.6692 - accuracy: 0.7952 - val_loss: 0.6540 - val_accuracy: 0.7988 - 48s/epoch - 61ms/step
# Epoch 33/60
# 781/781 - 47s - loss: 0.6624 - accuracy: 0.7976 - val_loss: 0.6465 - val_accuracy: 0.8027 - 47s/epoch - 60ms/step
# Epoch 34/60
# 781/781 - 47s - loss: 0.6546 - accuracy: 0.8015 - val_loss: 0.6978 - val_accuracy: 0.7885 - 47s/epoch - 60ms/step
# Epoch 35/60
# 781/781 - 48s - loss: 0.6468 - accuracy: 0.8040 - val_loss: 0.6659 - val_accuracy: 0.7971 - 48s/epoch - 61ms/step
# Epoch 36/60
# 781/781 - 47s - loss: 0.6421 - accuracy: 0.8048 - val_loss: 0.6889 - val_accuracy: 0.7938 - 47s/epoch - 60ms/step
# Epoch 37/60
# 781/781 - 48s - loss: 0.6317 - accuracy: 0.8078 - val_loss: 0.6438 - val_accuracy: 0.8082 - 48s/epoch - 61ms/step
# Epoch 38/60
# 781/781 - 47s - loss: 0.6304 - accuracy: 0.8102 - val_loss: 0.6161 - val_accuracy: 0.8119 - 47s/epoch - 60ms/step
# Epoch 39/60
# 781/781 - 48s - loss: 0.6242 - accuracy: 0.8128 - val_loss: 0.6190 - val_accuracy: 0.8182 - 48s/epoch - 61ms/step
# Epoch 40/60
# 781/781 - 47s - loss: 0.6159 - accuracy: 0.8147 - val_loss: 0.5926 - val_accuracy: 0.8195 - 47s/epoch - 60ms/step
# Epoch 41/60
# 781/781 - 47s - loss: 0.6147 - accuracy: 0.8153 - val_loss: 0.6677 - val_accuracy: 0.8053 - 47s/epoch - 60ms/step
# Epoch 42/60
# 781/781 - 47s - loss: 0.6054 - accuracy: 0.8195 - val_loss: 0.6450 - val_accuracy: 0.8079 - 47s/epoch - 60ms/step
# Epoch 43/60
# 781/781 - 47s - loss: 0.6034 - accuracy: 0.8203 - val_loss: 0.5910 - val_accuracy: 0.8298 - 47s/epoch - 60ms/step
# Epoch 44/60
# 781/781 - 47s - loss: 0.5964 - accuracy: 0.8227 - val_loss: 0.6057 - val_accuracy: 0.8196 - 47s/epoch - 61ms/step
# Epoch 45/60
# 781/781 - 47s - loss: 0.5948 - accuracy: 0.8222 - val_loss: 0.6264 - val_accuracy: 0.8170 - 47s/epoch - 60ms/step
# Epoch 46/60
# 781/781 - 48s - loss: 0.5890 - accuracy: 0.8276 - val_loss: 0.5829 - val_accuracy: 0.8280 - 48s/epoch - 61ms/step
# Epoch 47/60
# 781/781 - 48s - loss: 0.5873 - accuracy: 0.8281 - val_loss: 0.6074 - val_accuracy: 0.8239 - 48s/epoch - 61ms/step
# Epoch 48/60
# 781/781 - 47s - loss: 0.5762 - accuracy: 0.8303 - val_loss: 0.6063 - val_accuracy: 0.8242 - 47s/epoch - 61ms/step
# Epoch 49/60
# 781/781 - 48s - loss: 0.5732 - accuracy: 0.8340 - val_loss: 0.5762 - val_accuracy: 0.8334 - 48s/epoch - 61ms/step
# Epoch 50/60
# 781/781 - 48s - loss: 0.5710 - accuracy: 0.8333 - val_loss: 0.6676 - val_accuracy: 0.8075 - 48s/epoch - 61ms/step
# Epoch 51/60
# 781/781 - 48s - loss: 0.5690 - accuracy: 0.8321 - val_loss: 0.5982 - val_accuracy: 0.8271 - 48s/epoch - 61ms/step
# Epoch 52/60
# 781/781 - 47s - loss: 0.5650 - accuracy: 0.8349 - val_loss: 0.6255 - val_accuracy: 0.8169 - 47s/epoch - 61ms/step
# Epoch 53/60
# 781/781 - 48s - loss: 0.5565 - accuracy: 0.8372 - val_loss: 0.6534 - val_accuracy: 0.8151 - 48s/epoch - 61ms/step
# Epoch 54/60
# 781/781 - 47s - loss: 0.5601 - accuracy: 0.8377 - val_loss: 0.5871 - val_accuracy: 0.8328 - 47s/epoch - 61ms/step
# Epoch 55/60
# 781/781 - 48s - loss: 0.5558 - accuracy: 0.8387 - val_loss: 0.6317 - val_accuracy: 0.8222 - 48s/epoch - 61ms/step
# Epoch 56/60
# 781/781 - 48s - loss: 0.5464 - accuracy: 0.8437 - val_loss: 0.5816 - val_accuracy: 0.8373 - 48s/epoch - 61ms/step
# Epoch 57/60
# 781/781 - 47s - loss: 0.5437 - accuracy: 0.8441 - val_loss: 0.6177 - val_accuracy: 0.8231 - 47s/epoch - 61ms/step
# Epoch 58/60
# 781/781 - 47s - loss: 0.5388 - accuracy: 0.8447 - val_loss: 0.6482 - val_accuracy: 0.8180 - 47s/epoch - 61ms/step
# Epoch 59/60
# 781/781 - 48s - loss: 0.5405 - accuracy: 0.8449 - val_loss: 0.6945 - val_accuracy: 0.8060 - 48s/epoch - 61ms/step
# Epoch 60/60
# 781/781 - 48s - loss: 0.5393 - accuracy: 0.8456 - val_loss: 0.6235 - val_accuracy: 0.8229 - 48s/epoch - 61ms/step

# %%
#Plot training and validation loss
plt.figure(figsize=(10,5), dpi = 80)
plt.plot(Epochs_range, history.history['loss'])
plt.plot(Epochs_range, history.history['val_loss'])
plt.grid()
#Label the figures
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend(['Training', 'Validation'])

#Plot training and validation accuracy
plt.figure(figsize=(10,5), dpi = 80)
plt.plot(Epochs_range, history.history['accuracy'])
plt.plot(Epochs_range, history.history['val_accuracy'])
plt.grid()
#Label the figures
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.legend(['Training', 'Validation'])

# %% [markdown]
# #Model Evaluation and Predictions

# %%
#Model prediction on test data
y_pred = opt_model.predict(x_test/255.0)

#Get prediction classes
y_pred_classes = np.argmax(y_pred, axis=1)

#Get prediction probabilities
y_pred_prob = np.max(y_pred, axis=1)

#Get original labels from encoded ones
y_test = np.argmax(y_test, axis=1)

#Calculate model confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

#Plot model confusion matrix
plt.figure(figsize=(12, 8),dpi=80)
sns.heatmap(conf_matrix,
            xticklabels=list(classes.values()),
            yticklabels=list(classes.values()),
            annot=True,
            fmt='d')
#Label the plot
plt.title('Confusion Matrix')
plt.ylabel('Ground Truth')
plt.xlabel('Predictions')
plt.show()

#Print classification report
print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1000
#            1       0.93      0.91      0.92      1000
#            2       0.79      0.73      0.76      1000
#            3       0.75      0.56      0.64      1000
#            4       0.78      0.81      0.80      1000
#            5       0.82      0.69      0.75      1000
#            6       0.74      0.93      0.83      1000
#            7       0.85      0.87      0.86      1000
#            8       0.87      0.94      0.90      1000
#            9       0.84      0.94      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
#Plot model predicitons with true labels
fig = plt.figure(figsize=(2 * Cols - 1, 3 * Rows - 1))
#Iterate over the grid
for i in range(Cols):
  for j in range(Rows):
    #Get random index
    ind = random.randint(0, len(y_test))
    ax = fig.add_subplot(Rows, Cols, i * Rows + j + 1)
    ax.axis('off')
    #Display the image
    ax.imshow(x_test.astype(int)[ind])
    #Print original class with prediction class and probability
    pred_label = classes[y_pred_classes[ind]]
    pred_proba = y_pred_prob[ind]
    true_label = classes[y_test[ind]]
    ax.set_title("pred: {}\nscore: {:.3}\ntrue: {}".format(
            pred_label, pred_proba, true_label))
plt.show()
