# %% [markdown]
# #Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# #Get Dataset

# %%
#Get data from gdrive and unzip
# !unzip -q /content/gdrive/MyDrive/Intel_Image_Data.zip

# %% [markdown]
# #Load Dataset

# %%
import os
import numpy as np

#Base directory
base_dir = 'Intel_Image_Data/'

#Data directories
buildings_dir = os.path.join(base_dir, 'buildings')
forest_dir = os.path.join(base_dir, 'forest')
glacier_dir = os.path.join(base_dir, 'glacier')
mountain_dir = os.path.join(base_dir, 'mountain')
sea_dir = os.path.join(base_dir, 'sea')
street_dir = os.path.join(base_dir, 'street')
#File names
buildings_fnames = os.listdir( buildings_dir )
forest_fnames = os.listdir( forest_dir )
glacier_fnames = os.listdir( glacier_dir )
mountain_fnames = os.listdir( mountain_dir )
sea_fnames = os.listdir( sea_dir )
street_fnames = os.listdir( street_dir )

# %% [markdown]
# #EDA

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#Create a Grid and plot images from each class
nrows = 12
ncols = 4

pic_index = 0 

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_building_pix = [os.path.join(buildings_dir, fname) 
                for fname in buildings_fnames[ pic_index-8:pic_index] 
               ]

next_forest_pix = [os.path.join(forest_dir, fname) 
                for fname in forest_fnames[ pic_index-8:pic_index]
               ]

next_glacier_pix = [os.path.join(glacier_dir, fname) 
                for fname in glacier_fnames[ pic_index-8:pic_index]
               ]

next_mountain_pix = [os.path.join(mountain_dir, fname) 
                for fname in mountain_fnames[ pic_index-8:pic_index] 
               ]

next_sea_pix = [os.path.join(sea_dir, fname) 
                for fname in sea_fnames[ pic_index-8:pic_index]
               ]

next_street_pix = [os.path.join(street_dir, fname) 
                for fname in street_fnames[ pic_index-8:pic_index]]


for i, img_path in enumerate(next_building_pix+
                             next_forest_pix+
                             next_glacier_pix+
                             next_mountain_pix+
                             next_sea_pix+
                             next_street_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Pre-Processing

# %%
from skimage.transform import resize
from skimage.io import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Image generator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

#Batch size and epochs
batches = 1024
epochs = 50

#Load data using generator
train_im = datagen.flow_from_directory(
    base_dir,
    batch_size=batches,
    target_size=(150,150),
    class_mode="categorical",
    subset="training"
)

val_im = datagen.flow_from_directory(
    base_dir,
    batch_size=batches,
    target_size=(150,150),
    class_mode="categorical",
    subset="validation",
)


#Test images in numpy array
test_img_path = val_im.filepaths
test_imgs1 = []
for img in test_img_path:
  img_array = imread(img)
  img_resize = resize(img_array, (150,150,3))
  test_imgs1.append(img_resize)
test_imgs1=np.array(test_imgs1)

#True test labels
y_test1 = val_im.classes
# Out:
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.

# %% [markdown]
# #Classification Report and Confusion Matrix

# %%
import seaborn as sns
from sklearn import metrics
sns.set_theme(style='whitegrid', palette='Dark2')

#Class labels
LABELS = {0:'Buildings',
          1:'Forest',
          2:'Glacier',
          3:'Mountain',
          4:'Sea',
          5:'Street'}

#Plot confusion matrix
def conf_clf(ytrue, ypred):
    print(metrics.classification_report(ytrue,
                                        ypred,
                                        target_names=[l for l in list(LABELS.values())]))
    matrix = metrics.confusion_matrix(ytrue, ypred)
    plt.figure(figsize=(8, 8),dpi=100)
    sns.heatmap(matrix,
                cmap='Blues',
                linecolor='white',
                linewidths=1,
                xticklabels=list(LABELS.values()),
                yticklabels=list(LABELS.values()),
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('Ground Truth')
    plt.xlabel('Predictions')

# %% [markdown]
# #CNN Model

# %%
import tensorflow as tf

#Create a base CNN model using keras
def MODEL(initializer):
  model = tf.keras.models.Sequential([
      #CNN layers
      tf.keras.layers.Conv2D(16, (3,3),
                             activation='relu',
                             input_shape=(150,150, 3),
                             kernel_initializer=initializer,
                             kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0,l2=0.02)),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Conv2D(32, (3,3),
                             activation='relu',
                             kernel_initializer=initializer,
                             kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0,l2=0.02)),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Flatten(),
      #Fully connected layers
      tf.keras.layers.Dense(64, activation='relu',
                            kernel_initializer=initializer,
                            kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0,l2=0.02)),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(6, activation='softmax',
                            kernel_initializer=initializer)
  ])
  return model

# %% [markdown]
# #Baseline

# %% [markdown]
# ##Training

# %%
#Create the model
model1 = MODEL(initializer = "GlorotUniform")

#Compile model with optimizer and loss
model1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

#Train model using training data
hist_1 = model1.fit(train_im,
                    validation_data=val_im,
                    epochs=epochs,
                    batch_size=batches,
                    verbose=2)

#Model Predictions
pred1 = np.argmax(model1.predict(test_imgs1, verbose=0),axis=1)
# Out:
# Epoch 1/50
# 11/11 - 19s - loss: 4.7109 - accuracy: 0.2147 - val_loss: 3.4838 - val_accuracy: 0.2364 - 19s/epoch - 2s/step
# Epoch 2/50
# 11/11 - 16s - loss: 3.2051 - accuracy: 0.3052 - val_loss: 3.0212 - val_accuracy: 0.3399 - 16s/epoch - 1s/step
# Epoch 3/50
# 11/11 - 16s - loss: 2.7377 - accuracy: 0.3443 - val_loss: 2.5396 - val_accuracy: 0.3534 - 16s/epoch - 1s/step
# Epoch 4/50
# 11/11 - 16s - loss: 2.3495 - accuracy: 0.4030 - val_loss: 2.2207 - val_accuracy: 0.4219 - 16s/epoch - 1s/step
# Epoch 5/50
# 11/11 - 16s - loss: 2.0571 - accuracy: 0.4662 - val_loss: 1.9555 - val_accuracy: 0.5232 - 16s/epoch - 1s/step
# Epoch 6/50
# 11/11 - 16s - loss: 1.8403 - accuracy: 0.5300 - val_loss: 1.7808 - val_accuracy: 0.5578 - 16s/epoch - 1s/step
# Epoch 7/50
# 11/11 - 16s - loss: 1.7172 - accuracy: 0.5486 - val_loss: 1.6851 - val_accuracy: 0.5535 - 16s/epoch - 1s/step
# Epoch 8/50
# 11/11 - 16s - loss: 1.6218 - accuracy: 0.5662 - val_loss: 1.5894 - val_accuracy: 0.5699 - 16s/epoch - 1s/step
# Epoch 9/50
# 11/11 - 16s - loss: 1.5435 - accuracy: 0.5740 - val_loss: 1.5321 - val_accuracy: 0.5660 - 16s/epoch - 1s/step
# Epoch 10/50
# 11/11 - 16s - loss: 1.4937 - accuracy: 0.5829 - val_loss: 1.4866 - val_accuracy: 0.5888 - 16s/epoch - 1s/step
# Epoch 11/50
# 11/11 - 16s - loss: 1.4275 - accuracy: 0.6024 - val_loss: 1.4374 - val_accuracy: 0.6009 - 16s/epoch - 1s/step
# Epoch 12/50
# 11/11 - 16s - loss: 1.3956 - accuracy: 0.6131 - val_loss: 1.3929 - val_accuracy: 0.6205 - 16s/epoch - 1s/step
# Epoch 13/50
# 11/11 - 16s - loss: 1.3613 - accuracy: 0.6194 - val_loss: 1.4083 - val_accuracy: 0.6049 - 16s/epoch - 1s/step
# Epoch 14/50
# 11/11 - 16s - loss: 1.3461 - accuracy: 0.6204 - val_loss: 1.3646 - val_accuracy: 0.6223 - 16s/epoch - 1s/step
# Epoch 15/50
# 11/11 - 16s - loss: 1.3155 - accuracy: 0.6267 - val_loss: 1.3145 - val_accuracy: 0.6255 - 16s/epoch - 1s/step
# Epoch 16/50
# 11/11 - 16s - loss: 1.2930 - accuracy: 0.6378 - val_loss: 1.3031 - val_accuracy: 0.6377 - 16s/epoch - 1s/step
# Epoch 17/50
# 11/11 - 16s - loss: 1.2727 - accuracy: 0.6385 - val_loss: 1.2932 - val_accuracy: 0.6337 - 16s/epoch - 1s/step
# Epoch 18/50
# 11/11 - 16s - loss: 1.2451 - accuracy: 0.6549 - val_loss: 1.2431 - val_accuracy: 0.6626 - 16s/epoch - 1s/step
# Epoch 19/50
# 11/11 - 16s - loss: 1.2338 - accuracy: 0.6546 - val_loss: 1.2420 - val_accuracy: 0.6437 - 16s/epoch - 1s/step
# Epoch 20/50
# 11/11 - 16s - loss: 1.2205 - accuracy: 0.6589 - val_loss: 1.2319 - val_accuracy: 0.6651 - 16s/epoch - 1s/step
# Epoch 21/50
# 11/11 - 16s - loss: 1.2178 - accuracy: 0.6501 - val_loss: 1.1985 - val_accuracy: 0.6805 - 16s/epoch - 1s/step
# Epoch 22/50
# 11/11 - 16s - loss: 1.1992 - accuracy: 0.6576 - val_loss: 1.1989 - val_accuracy: 0.6683 - 16s/epoch - 1s/step
# Epoch 23/50
# 11/11 - 16s - loss: 1.1699 - accuracy: 0.6758 - val_loss: 1.1739 - val_accuracy: 0.6787 - 16s/epoch - 1s/step
# Epoch 24/50
# 11/11 - 16s - loss: 1.1677 - accuracy: 0.6645 - val_loss: 1.1601 - val_accuracy: 0.6976 - 16s/epoch - 1s/step
# Epoch 25/50
# 11/11 - 16s - loss: 1.1582 - accuracy: 0.6766 - val_loss: 1.2071 - val_accuracy: 0.6612 - 16s/epoch - 1s/step
# Epoch 26/50
# 11/11 - 16s - loss: 1.1520 - accuracy: 0.6730 - val_loss: 1.1477 - val_accuracy: 0.6940 - 16s/epoch - 1s/step
# Epoch 27/50
# 11/11 - 16s - loss: 1.1450 - accuracy: 0.6739 - val_loss: 1.1571 - val_accuracy: 0.6879 - 16s/epoch - 1s/step
# Epoch 28/50
# 11/11 - 16s - loss: 1.1335 - accuracy: 0.6841 - val_loss: 1.1344 - val_accuracy: 0.6772 - 16s/epoch - 1s/step
# Epoch 29/50
# 11/11 - 16s - loss: 1.1161 - accuracy: 0.6914 - val_loss: 1.1162 - val_accuracy: 0.6951 - 16s/epoch - 1s/step
# Epoch 30/50
# 11/11 - 16s - loss: 1.1078 - accuracy: 0.6892 - val_loss: 1.1033 - val_accuracy: 0.6954 - 16s/epoch - 1s/step
# Epoch 31/50
# 11/11 - 16s - loss: 1.0887 - accuracy: 0.6954 - val_loss: 1.1000 - val_accuracy: 0.7004 - 16s/epoch - 1s/step
# Epoch 32/50
# 11/11 - 16s - loss: 1.0886 - accuracy: 0.6979 - val_loss: 1.0808 - val_accuracy: 0.7044 - 16s/epoch - 1s/step
# Epoch 33/50
# 11/11 - 16s - loss: 1.0874 - accuracy: 0.6908 - val_loss: 1.1783 - val_accuracy: 0.6601 - 16s/epoch - 1s/step
# Epoch 34/50
# 11/11 - 16s - loss: 1.1092 - accuracy: 0.6776 - val_loss: 1.1909 - val_accuracy: 0.6516 - 16s/epoch - 1s/step
# Epoch 35/50
# 11/11 - 16s - loss: 1.1067 - accuracy: 0.6883 - val_loss: 1.1330 - val_accuracy: 0.6815 - 16s/epoch - 1s/step
# Epoch 36/50
# 11/11 - 16s - loss: 1.0947 - accuracy: 0.6887 - val_loss: 1.1020 - val_accuracy: 0.6897 - 16s/epoch - 1s/step
# Epoch 37/50
# 11/11 - 16s - loss: 1.0671 - accuracy: 0.7022 - val_loss: 1.0759 - val_accuracy: 0.7047 - 16s/epoch - 1s/step
# Epoch 38/50
# 11/11 - 16s - loss: 1.0488 - accuracy: 0.7059 - val_loss: 1.0504 - val_accuracy: 0.7129 - 16s/epoch - 1s/step
# Epoch 39/50
# 11/11 - 16s - loss: 1.0446 - accuracy: 0.7113 - val_loss: 1.0539 - val_accuracy: 0.7122 - 16s/epoch - 1s/step
# Epoch 40/50
# 11/11 - 16s - loss: 1.0443 - accuracy: 0.7131 - val_loss: 1.0447 - val_accuracy: 0.7147 - 16s/epoch - 1s/step
# Epoch 41/50
# 11/11 - 16s - loss: 1.0454 - accuracy: 0.7066 - val_loss: 1.0702 - val_accuracy: 0.7026 - 16s/epoch - 1s/step
# Epoch 42/50
# 11/11 - 16s - loss: 1.0354 - accuracy: 0.7070 - val_loss: 1.0553 - val_accuracy: 0.7054 - 16s/epoch - 1s/step
# Epoch 43/50
# 11/11 - 16s - loss: 1.0346 - accuracy: 0.7091 - val_loss: 1.0239 - val_accuracy: 0.7186 - 16s/epoch - 1s/step
# Epoch 44/50
# 11/11 - 16s - loss: 1.0326 - accuracy: 0.7110 - val_loss: 1.0230 - val_accuracy: 0.7118 - 16s/epoch - 1s/step
# Epoch 45/50
# 11/11 - 16s - loss: 1.0553 - accuracy: 0.6977 - val_loss: 1.0566 - val_accuracy: 0.7068 - 16s/epoch - 1s/step
# Epoch 46/50
# 11/11 - 16s - loss: 1.0352 - accuracy: 0.7121 - val_loss: 1.0264 - val_accuracy: 0.7175 - 16s/epoch - 1s/step
# Epoch 47/50
# 11/11 - 16s - loss: 1.0109 - accuracy: 0.7169 - val_loss: 1.0332 - val_accuracy: 0.7111 - 16s/epoch - 1s/step
# Epoch 48/50
# 11/11 - 16s - loss: 1.0006 - accuracy: 0.7213 - val_loss: 1.0272 - val_accuracy: 0.7054 - 16s/epoch - 1s/step
# Epoch 49/50
# 11/11 - 16s - loss: 1.0004 - accuracy: 0.7240 - val_loss: 1.0110 - val_accuracy: 0.7233 - 16s/epoch - 1s/step
# Epoch 50/50
# 11/11 - 16s - loss: 0.9992 - accuracy: 0.7155 - val_loss: 1.0154 - val_accuracy: 0.7115 - 16s/epoch - 1s/step

# %% [markdown]
# ##Loss and Accuracy Plot

# %%
#Plot loss and accuracy plots
acc1 = hist_1.history['accuracy']
val_acc1 = hist_1.history['val_accuracy']
loss1 = hist_1.history['loss']
val_loss1 = hist_1.history['val_loss']

epochs = range(len(acc1))

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, acc1, label='Training accuracy')
plt.plot(epochs, val_acc1, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(["Train", "Val"])

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, loss1, label='Training Loss')
plt.plot(epochs, val_loss1, label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(["Train", "Val"]);

# %% [markdown]
# ##Classification Report and Confusion Matrix

# %%
conf_clf(y_test1, pred1)
# Out:
#               precision    recall  f1-score   support
#
#    Buildings       0.76      0.51      0.61       438
#       Forest       0.91      0.91      0.91       454
#      Glacier       0.58      0.88      0.70       480
#     Mountain       0.71      0.60      0.65       502
#          Sea       0.73      0.47      0.57       454
#       Street       0.70      0.89      0.78       476
#
#     accuracy                           0.71      2804
#    macro avg       0.73      0.71      0.70      2804
# weighted avg       0.73      0.71      0.70      2804

# %% [markdown]
# #Weights Initialization

# %% [markdown]
# ##Training

# %%
#Create model with HeNormal initialization
model2 = MODEL(initializer = "HeNormal")

#Compile the model with optimizer and loss
model2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

epochs=50

#Model training
hist_2 = model2.fit(train_im,
                    validation_data=val_im,
                    epochs=epochs,
                    batch_size=batches,
                    verbose=2)

#Model Predictions
pred2 = np.argmax(model2.predict(test_imgs1, verbose=0),axis=1)
# Out:
# Epoch 1/50
# 11/11 - 19s - loss: 10.1680 - accuracy: 0.1937 - val_loss: 5.5163 - val_accuracy: 0.3185 - 19s/epoch - 2s/step
# Epoch 2/50
# 11/11 - 17s - loss: 5.3281 - accuracy: 0.2589 - val_loss: 5.1241 - val_accuracy: 0.2607 - 17s/epoch - 2s/step
# Epoch 3/50
# 11/11 - 17s - loss: 4.8961 - accuracy: 0.2896 - val_loss: 4.7317 - val_accuracy: 0.2903 - 17s/epoch - 2s/step
# Epoch 4/50
# 11/11 - 17s - loss: 4.4952 - accuracy: 0.3212 - val_loss: 4.3543 - val_accuracy: 0.3245 - 17s/epoch - 2s/step
# Epoch 5/50
# 11/11 - 17s - loss: 4.1389 - accuracy: 0.3169 - val_loss: 4.0126 - val_accuracy: 0.3655 - 17s/epoch - 2s/step
# Epoch 6/50
# 11/11 - 17s - loss: 3.8320 - accuracy: 0.3952 - val_loss: 3.6961 - val_accuracy: 0.4932 - 17s/epoch - 2s/step
# Epoch 7/50
# 11/11 - 17s - loss: 3.5520 - accuracy: 0.4638 - val_loss: 3.4774 - val_accuracy: 0.5235 - 17s/epoch - 2s/step
# Epoch 8/50
# 11/11 - 17s - loss: 3.3515 - accuracy: 0.4957 - val_loss: 3.3077 - val_accuracy: 0.5439 - 17s/epoch - 2s/step
# Epoch 9/50
# 11/11 - 17s - loss: 3.2169 - accuracy: 0.4955 - val_loss: 3.1912 - val_accuracy: 0.5460 - 17s/epoch - 2s/step
# Epoch 10/50
# 11/11 - 17s - loss: 3.0896 - accuracy: 0.5189 - val_loss: 3.0866 - val_accuracy: 0.5364 - 17s/epoch - 2s/step
# Epoch 11/50
# 11/11 - 17s - loss: 3.0073 - accuracy: 0.5268 - val_loss: 2.9791 - val_accuracy: 0.5471 - 17s/epoch - 2s/step
# Epoch 12/50
# 11/11 - 17s - loss: 2.9077 - accuracy: 0.5508 - val_loss: 2.9079 - val_accuracy: 0.5481 - 17s/epoch - 2s/step
# Epoch 13/50
# 11/11 - 17s - loss: 2.8181 - accuracy: 0.5562 - val_loss: 2.7927 - val_accuracy: 0.5621 - 17s/epoch - 2s/step
# Epoch 14/50
# 11/11 - 17s - loss: 2.7237 - accuracy: 0.5658 - val_loss: 2.7087 - val_accuracy: 0.5695 - 17s/epoch - 2s/step
# Epoch 15/50
# 11/11 - 17s - loss: 2.6464 - accuracy: 0.5682 - val_loss: 2.6428 - val_accuracy: 0.5688 - 17s/epoch - 2s/step
# Epoch 16/50
# 11/11 - 17s - loss: 2.5737 - accuracy: 0.5771 - val_loss: 2.5808 - val_accuracy: 0.5999 - 17s/epoch - 2s/step
# Epoch 17/50
# 11/11 - 17s - loss: 2.5219 - accuracy: 0.5790 - val_loss: 2.5180 - val_accuracy: 0.6056 - 17s/epoch - 2s/step
# Epoch 18/50
# 11/11 - 16s - loss: 2.4612 - accuracy: 0.5906 - val_loss: 2.4991 - val_accuracy: 0.5884 - 16s/epoch - 1s/step
# Epoch 19/50
# 11/11 - 16s - loss: 2.4255 - accuracy: 0.5878 - val_loss: 2.4149 - val_accuracy: 0.6013 - 16s/epoch - 1s/step
# Epoch 20/50
# 11/11 - 16s - loss: 2.3817 - accuracy: 0.5866 - val_loss: 2.4059 - val_accuracy: 0.6059 - 16s/epoch - 1s/step
# Epoch 21/50
# 11/11 - 17s - loss: 2.3321 - accuracy: 0.5947 - val_loss: 2.3144 - val_accuracy: 0.6348 - 17s/epoch - 2s/step
# Epoch 22/50
# 11/11 - 17s - loss: 2.2860 - accuracy: 0.6039 - val_loss: 2.3098 - val_accuracy: 0.6095 - 17s/epoch - 2s/step
# Epoch 23/50
# 11/11 - 16s - loss: 2.2387 - accuracy: 0.6132 - val_loss: 2.2646 - val_accuracy: 0.6359 - 16s/epoch - 1s/step
# Epoch 24/50
# 11/11 - 17s - loss: 2.2088 - accuracy: 0.6128 - val_loss: 2.2906 - val_accuracy: 0.5881 - 17s/epoch - 2s/step
# Epoch 25/50
# 11/11 - 17s - loss: 2.1860 - accuracy: 0.6061 - val_loss: 2.1815 - val_accuracy: 0.6419 - 17s/epoch - 2s/step
# Epoch 26/50
# 11/11 - 19s - loss: 2.1374 - accuracy: 0.6257 - val_loss: 2.1693 - val_accuracy: 0.6359 - 19s/epoch - 2s/step
# Epoch 27/50
# 11/11 - 17s - loss: 2.1066 - accuracy: 0.6243 - val_loss: 2.1045 - val_accuracy: 0.6583 - 17s/epoch - 2s/step
# Epoch 28/50
# 11/11 - 17s - loss: 2.0817 - accuracy: 0.6272 - val_loss: 2.1062 - val_accuracy: 0.6387 - 17s/epoch - 2s/step
# Epoch 29/50
# 11/11 - 16s - loss: 2.0606 - accuracy: 0.6274 - val_loss: 2.0342 - val_accuracy: 0.6815 - 16s/epoch - 1s/step
# Epoch 30/50
# 11/11 - 16s - loss: 2.0359 - accuracy: 0.6356 - val_loss: 2.0549 - val_accuracy: 0.6605 - 16s/epoch - 1s/step
# Epoch 31/50
# 11/11 - 16s - loss: 2.0033 - accuracy: 0.6383 - val_loss: 2.0721 - val_accuracy: 0.6223 - 16s/epoch - 1s/step
# Epoch 32/50
# 11/11 - 17s - loss: 1.9781 - accuracy: 0.6391 - val_loss: 2.0069 - val_accuracy: 0.6512 - 17s/epoch - 2s/step
# Epoch 33/50
# 11/11 - 16s - loss: 1.9563 - accuracy: 0.6418 - val_loss: 1.9568 - val_accuracy: 0.6840 - 16s/epoch - 1s/step
# Epoch 34/50
# 11/11 - 16s - loss: 1.9496 - accuracy: 0.6348 - val_loss: 1.9356 - val_accuracy: 0.6787 - 16s/epoch - 1s/step
# Epoch 35/50
# 11/11 - 17s - loss: 1.9213 - accuracy: 0.6398 - val_loss: 1.9398 - val_accuracy: 0.6680 - 17s/epoch - 2s/step
# Epoch 36/50
# 11/11 - 17s - loss: 1.8904 - accuracy: 0.6457 - val_loss: 1.9098 - val_accuracy: 0.6673 - 17s/epoch - 2s/step
# Epoch 37/50
# 11/11 - 16s - loss: 1.8868 - accuracy: 0.6434 - val_loss: 1.8978 - val_accuracy: 0.6730 - 16s/epoch - 1s/step
# Epoch 38/50
# 11/11 - 16s - loss: 1.8746 - accuracy: 0.6484 - val_loss: 1.8560 - val_accuracy: 0.6769 - 16s/epoch - 1s/step
# Epoch 39/50
# 11/11 - 16s - loss: 1.8492 - accuracy: 0.6500 - val_loss: 1.8353 - val_accuracy: 0.6776 - 16s/epoch - 1s/step
# Epoch 40/50
# 11/11 - 16s - loss: 1.8318 - accuracy: 0.6603 - val_loss: 1.8276 - val_accuracy: 0.6958 - 16s/epoch - 1s/step
# Epoch 41/50
# 11/11 - 16s - loss: 1.8074 - accuracy: 0.6577 - val_loss: 1.8231 - val_accuracy: 0.6908 - 16s/epoch - 1s/step
# Epoch 42/50
# 11/11 - 16s - loss: 1.8062 - accuracy: 0.6496 - val_loss: 1.8824 - val_accuracy: 0.6494 - 16s/epoch - 1s/step
# Epoch 43/50
# 11/11 - 17s - loss: 1.7971 - accuracy: 0.6542 - val_loss: 1.7801 - val_accuracy: 0.6972 - 17s/epoch - 2s/step
# Epoch 44/50
# 11/11 - 17s - loss: 1.7648 - accuracy: 0.6616 - val_loss: 1.7717 - val_accuracy: 0.6937 - 17s/epoch - 2s/step
# Epoch 45/50
# 11/11 - 17s - loss: 1.7494 - accuracy: 0.6581 - val_loss: 1.7385 - val_accuracy: 0.7051 - 17s/epoch - 2s/step
# Epoch 46/50
# 11/11 - 17s - loss: 1.7464 - accuracy: 0.6578 - val_loss: 1.7261 - val_accuracy: 0.7086 - 17s/epoch - 2s/step
# Epoch 47/50
# 11/11 - 17s - loss: 1.7205 - accuracy: 0.6654 - val_loss: 1.6836 - val_accuracy: 0.7254 - 17s/epoch - 2s/step
# Epoch 48/50
# 11/11 - 17s - loss: 1.6971 - accuracy: 0.6785 - val_loss: 1.6751 - val_accuracy: 0.7208 - 17s/epoch - 2s/step
# Epoch 49/50
# 11/11 - 17s - loss: 1.6943 - accuracy: 0.6709 - val_loss: 1.6385 - val_accuracy: 0.7386 - 17s/epoch - 2s/step
# Epoch 50/50
# 11/11 - 17s - loss: 1.6781 - accuracy: 0.6744 - val_loss: 1.6575 - val_accuracy: 0.7290 - 17s/epoch - 2s/step

# %% [markdown]
# ##Loss and Accuracy Plot

# %%
acc2 = hist_2.history['accuracy']
val_acc2 = hist_2.history['val_accuracy']
loss2 = hist_2.history['loss']
val_loss2 = hist_2.history['val_loss']

epochs = range(len(acc2))

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, acc2, label='Training accuracy')
plt.plot(epochs, val_acc2, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(["Train", "Val"])

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, loss2, label='Training Loss')
plt.plot(epochs, val_loss2, label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(["Train", "Val"]);

# %% [markdown]
# ##Classification report and Confusion matrix

# %%
conf_clf(y_test1, pred2)
# Out:
#               precision    recall  f1-score   support
#
#    Buildings       0.76      0.61      0.67       438
#       Forest       0.89      0.92      0.90       454
#      Glacier       0.66      0.79      0.72       480
#     Mountain       0.68      0.63      0.65       502
#          Sea       0.65      0.61      0.63       454
#       Street       0.74      0.81      0.78       476
#
#     accuracy                           0.73      2804
#    macro avg       0.73      0.73      0.73      2804
# weighted avg       0.73      0.73      0.73      2804

# %% [markdown]
# #Learning Rate Decay

# %% [markdown]
# ##Training

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

#Create model
model3 = MODEL(initializer = "GlorotUniform")

#Compile the model
model3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

epochs = 50
initial_learning_rate = 0.01

#ratio to decay the weight
decay = initial_learning_rate / epochs

#Function for the callback
def lr_time_based_decay(epoch, lr):
    return lr * 1 / (1 + decay * epoch)

#Declare callbacks
callbacks_list = [LearningRateScheduler(lr_time_based_decay, verbose=1)]


#Model training
hist_3 = model3.fit(train_im,
                    validation_data=val_im,
                    epochs=epochs,
                    batch_size=batches,
                    callbacks=callbacks_list,
                    verbose=2)

#Model Predictions
pred3 = np.argmax(model3.predict(test_imgs1, verbose=0),axis=1)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# 11/11 - 21s - loss: 4.7033 - accuracy: 0.1858 - val_loss: 3.2470 - val_accuracy: 0.1740 - lr: 0.0010 - 21s/epoch - 2s/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0009998000874799553.
# Epoch 2/50
# 11/11 - 17s - loss: 3.0301 - accuracy: 0.2487 - val_loss: 2.8099 - val_accuracy: 0.3951 - lr: 9.9980e-04 - 17s/epoch - 2s/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0009994002858602087.
# Epoch 3/50
# 11/11 - 17s - loss: 2.5441 - accuracy: 0.4111 - val_loss: 2.3551 - val_accuracy: 0.5203 - lr: 9.9940e-04 - 17s/epoch - 2s/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0009988009951623015.
# Epoch 4/50
# 11/11 - 17s - loss: 2.1905 - accuracy: 0.4938 - val_loss: 2.0617 - val_accuracy: 0.5264 - lr: 9.9880e-04 - 17s/epoch - 2s/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0009980025676285312.
# Epoch 5/50
# 11/11 - 18s - loss: 1.9264 - accuracy: 0.5605 - val_loss: 1.8313 - val_accuracy: 0.5820 - lr: 9.9800e-04 - 18s/epoch - 2s/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0009970055878177272.
# Epoch 6/50
# 11/11 - 17s - loss: 1.7654 - accuracy: 0.5813 - val_loss: 1.7200 - val_accuracy: 0.5949 - lr: 9.9701e-04 - 17s/epoch - 2s/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.000995810639821633.
# Epoch 7/50
# 11/11 - 17s - loss: 1.6632 - accuracy: 0.5956 - val_loss: 1.6428 - val_accuracy: 0.5895 - lr: 9.9581e-04 - 17s/epoch - 2s/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0009944184235179403.
# Epoch 8/50
# 11/11 - 17s - loss: 1.5632 - accuracy: 0.6139 - val_loss: 1.5587 - val_accuracy: 0.6016 - lr: 9.9442e-04 - 17s/epoch - 2s/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0009928298706840426.
# Epoch 9/50
# 11/11 - 17s - loss: 1.4831 - accuracy: 0.6378 - val_loss: 1.5437 - val_accuracy: 0.5763 - lr: 9.9283e-04 - 17s/epoch - 2s/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0009910460285594016.
# Epoch 10/50
# 11/11 - 17s - loss: 1.4502 - accuracy: 0.6388 - val_loss: 1.4632 - val_accuracy: 0.6131 - lr: 9.9105e-04 - 17s/epoch - 2s/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0009890679435473598.
# Epoch 11/50
# 11/11 - 17s - loss: 1.4041 - accuracy: 0.6500 - val_loss: 1.4572 - val_accuracy: 0.5970 - lr: 9.8907e-04 - 17s/epoch - 2s/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0009868967773757446.
# Epoch 12/50
# 11/11 - 17s - loss: 1.3680 - accuracy: 0.6565 - val_loss: 1.4091 - val_accuracy: 0.6316 - lr: 9.8690e-04 - 17s/epoch - 2s/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0009845339231184147.
# Epoch 13/50
# 11/11 - 17s - loss: 1.3431 - accuracy: 0.6620 - val_loss: 1.3363 - val_accuracy: 0.6658 - lr: 9.8453e-04 - 17s/epoch - 2s/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0009819807727376596.
# Epoch 14/50
# 11/11 - 17s - loss: 1.3090 - accuracy: 0.6736 - val_loss: 1.3390 - val_accuracy: 0.6626 - lr: 9.8198e-04 - 17s/epoch - 2s/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0009792389492658468.
# Epoch 15/50
# 11/11 - 17s - loss: 1.3286 - accuracy: 0.6586 - val_loss: 1.3035 - val_accuracy: 0.6787 - lr: 9.7924e-04 - 17s/epoch - 2s/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0009763100744408007.
# Epoch 16/50
# 11/11 - 16s - loss: 1.2813 - accuracy: 0.6782 - val_loss: 1.3008 - val_accuracy: 0.6491 - lr: 9.7631e-04 - 16s/epoch - 1s/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0009731958267290851.
# Epoch 17/50
# 11/11 - 18s - loss: 1.2515 - accuracy: 0.6864 - val_loss: 1.2382 - val_accuracy: 0.6894 - lr: 9.7320e-04 - 18s/epoch - 2s/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0009698981733111679.
# Epoch 18/50
# 11/11 - 17s - loss: 1.2341 - accuracy: 0.6906 - val_loss: 1.2183 - val_accuracy: 0.7015 - lr: 9.6990e-04 - 17s/epoch - 2s/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0009664190797994173.
# Epoch 19/50
# 11/11 - 17s - loss: 1.2399 - accuracy: 0.6921 - val_loss: 1.2469 - val_accuracy: 0.6869 - lr: 9.6642e-04 - 17s/epoch - 2s/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0009627605682269739.
# Epoch 20/50
# 11/11 - 17s - loss: 1.2038 - accuracy: 0.6959 - val_loss: 1.2502 - val_accuracy: 0.6601 - lr: 9.6276e-04 - 17s/epoch - 2s/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0009589248909188279.
# Epoch 21/50
# 11/11 - 16s - loss: 1.1876 - accuracy: 0.7051 - val_loss: 1.1728 - val_accuracy: 0.7076 - lr: 9.5892e-04 - 16s/epoch - 1s/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0009549142404414344.
# Epoch 22/50
# 11/11 - 16s - loss: 1.1948 - accuracy: 0.6977 - val_loss: 1.1847 - val_accuracy: 0.7136 - lr: 9.5491e-04 - 16s/epoch - 1s/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0009507310394255563.
# Epoch 23/50
# 11/11 - 17s - loss: 1.1932 - accuracy: 0.6974 - val_loss: 1.2217 - val_accuracy: 0.6694 - lr: 9.5073e-04 - 17s/epoch - 2s/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0009463777085727261.
# Epoch 24/50
# 11/11 - 17s - loss: 1.1731 - accuracy: 0.7048 - val_loss: 1.1557 - val_accuracy: 0.7140 - lr: 9.4638e-04 - 17s/epoch - 2s/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0009418567825163638.
# Epoch 25/50
# 11/11 - 17s - loss: 1.1509 - accuracy: 0.7121 - val_loss: 1.1715 - val_accuracy: 0.7083 - lr: 9.4186e-04 - 17s/epoch - 2s/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0009371709097084122.
# Epoch 26/50
# 11/11 - 17s - loss: 1.1375 - accuracy: 0.7169 - val_loss: 1.1150 - val_accuracy: 0.7307 - lr: 9.3717e-04 - 17s/epoch - 2s/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0009323228523061064.
# Epoch 27/50
# 11/11 - 17s - loss: 1.1217 - accuracy: 0.7202 - val_loss: 1.1495 - val_accuracy: 0.7022 - lr: 9.3232e-04 - 17s/epoch - 2s/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0009273153702688248.
# Epoch 28/50
# 11/11 - 17s - loss: 1.1074 - accuracy: 0.7238 - val_loss: 1.1403 - val_accuracy: 0.7090 - lr: 9.2732e-04 - 17s/epoch - 2s/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0009221513371272998.
# Epoch 29/50
# 11/11 - 16s - loss: 1.1054 - accuracy: 0.7291 - val_loss: 1.1268 - val_accuracy: 0.7086 - lr: 9.2215e-04 - 16s/epoch - 1s/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0009168336819986992.
# Epoch 30/50
# 11/11 - 17s - loss: 1.0893 - accuracy: 0.7310 - val_loss: 1.1559 - val_accuracy: 0.6862 - lr: 9.1683e-04 - 17s/epoch - 2s/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0009113655052523668.
# Epoch 31/50
# 11/11 - 17s - loss: 1.0914 - accuracy: 0.7285 - val_loss: 1.1909 - val_accuracy: 0.6651 - lr: 9.1137e-04 - 17s/epoch - 2s/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0009057498469436365.
# Epoch 32/50
# 11/11 - 17s - loss: 1.1002 - accuracy: 0.7253 - val_loss: 1.1389 - val_accuracy: 0.7019 - lr: 9.0575e-04 - 17s/epoch - 2s/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0008999899182237673.
# Epoch 33/50
# 11/11 - 17s - loss: 1.0880 - accuracy: 0.7313 - val_loss: 1.0653 - val_accuracy: 0.7461 - lr: 8.9999e-04 - 17s/epoch - 2s/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0008940889276919404.
# Epoch 34/50
# 11/11 - 17s - loss: 1.0820 - accuracy: 0.7302 - val_loss: 1.1399 - val_accuracy: 0.6904 - lr: 8.9409e-04 - 17s/epoch - 2s/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0008880501970268393.
# Epoch 35/50
# 11/11 - 17s - loss: 1.0688 - accuracy: 0.7347 - val_loss: 1.0568 - val_accuracy: 0.7361 - lr: 8.8805e-04 - 17s/epoch - 2s/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0008818770452682762.
# Epoch 36/50
# 11/11 - 17s - loss: 1.0469 - accuracy: 0.7477 - val_loss: 1.0598 - val_accuracy: 0.7447 - lr: 8.8188e-04 - 17s/epoch - 2s/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0008755729044029359.
# Epoch 37/50
# 11/11 - 17s - loss: 1.0396 - accuracy: 0.7430 - val_loss: 1.0539 - val_accuracy: 0.7500 - lr: 8.7557e-04 - 17s/epoch - 2s/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0008691412614721709.
# Epoch 38/50
# 11/11 - 17s - loss: 1.0384 - accuracy: 0.7487 - val_loss: 1.0289 - val_accuracy: 0.7500 - lr: 8.6914e-04 - 17s/epoch - 2s/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0008625856007487409.
# Epoch 39/50
# 11/11 - 17s - loss: 1.0194 - accuracy: 0.7585 - val_loss: 1.0378 - val_accuracy: 0.7447 - lr: 8.6259e-04 - 17s/epoch - 2s/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.000855909519253872.
# Epoch 40/50
# 11/11 - 17s - loss: 1.0351 - accuracy: 0.7435 - val_loss: 1.0500 - val_accuracy: 0.7343 - lr: 8.5591e-04 - 17s/epoch - 2s/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0008491166111540109.
# Epoch 41/50
# 11/11 - 16s - loss: 1.0280 - accuracy: 0.7470 - val_loss: 1.0355 - val_accuracy: 0.7532 - lr: 8.4912e-04 - 16s/epoch - 1s/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.0008422104677636575.
# Epoch 42/50
# 11/11 - 17s - loss: 1.0318 - accuracy: 0.7474 - val_loss: 1.0431 - val_accuracy: 0.7382 - lr: 8.4221e-04 - 17s/epoch - 2s/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0008351948507165611.
# Epoch 43/50
# 11/11 - 17s - loss: 1.0105 - accuracy: 0.7564 - val_loss: 1.0481 - val_accuracy: 0.7304 - lr: 8.3519e-04 - 17s/epoch - 2s/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.0008280734032401367.
# Epoch 44/50
# 11/11 - 17s - loss: 1.0011 - accuracy: 0.7552 - val_loss: 1.0554 - val_accuracy: 0.7290 - lr: 8.2807e-04 - 17s/epoch - 2s/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.0008208499387723471.
# Epoch 45/50
# 11/11 - 17s - loss: 0.9938 - accuracy: 0.7521 - val_loss: 1.0302 - val_accuracy: 0.7336 - lr: 8.2085e-04 - 17s/epoch - 2s/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.0008135282100391519.
# Epoch 46/50
# 11/11 - 16s - loss: 0.9916 - accuracy: 0.7582 - val_loss: 1.0166 - val_accuracy: 0.7564 - lr: 8.1353e-04 - 16s/epoch - 1s/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.0008061119667916981.
# Epoch 47/50
# 11/11 - 17s - loss: 0.9858 - accuracy: 0.7622 - val_loss: 1.1358 - val_accuracy: 0.6833 - lr: 8.0611e-04 - 17s/epoch - 2s/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.0007986050711404764.
# Epoch 48/50
# 11/11 - 17s - loss: 0.9953 - accuracy: 0.7532 - val_loss: 0.9812 - val_accuracy: 0.7657 - lr: 7.9861e-04 - 17s/epoch - 2s/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.0007910113821356674.
# Epoch 49/50
# 11/11 - 16s - loss: 0.9830 - accuracy: 0.7597 - val_loss: 0.9792 - val_accuracy: 0.7696 - lr: 7.9101e-04 - 16s/epoch - 1s/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0007833346981274111.
# Epoch 50/50
# 11/11 - 16s - loss: 0.9860 - accuracy: 0.7596 - val_loss: 1.0087 - val_accuracy: 0.7464 - lr: 7.8333e-04 - 16s/epoch - 1s/step

# %% [markdown]
# ##Loss and Accuracy Plot

# %%
acc3 = hist_3.history['accuracy']
val_acc3 = hist_3.history['val_accuracy']
loss3 = hist_3.history['loss']
val_loss3 = hist_3.history['val_loss']

epochs = range(len(acc3))

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, acc3, label='Training accuracy')
plt.plot(epochs, val_acc3, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(["Train", "Val"])

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, loss3, label='Training Loss')
plt.plot(epochs, val_loss3, label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(["Train", "Val"]);

# %% [markdown]
# ##Confusion matrix and Classification Report

# %%
conf_clf(y_test1, pred3)
# Out:
#               precision    recall  f1-score   support
#
#    Buildings       0.86      0.58      0.69       438
#       Forest       0.93      0.93      0.93       454
#      Glacier       0.59      0.86      0.70       480
#     Mountain       0.69      0.66      0.67       502
#          Sea       0.74      0.60      0.66       454
#       Street       0.79      0.85      0.82       476
#
#     accuracy                           0.75      2804
#    macro avg       0.77      0.75      0.75      2804
# weighted avg       0.76      0.75      0.74      2804

# %% [markdown]
# #Batch Size

# %%
#Data Generator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

#Batch size
batches = 512

#Training generator
train_im = datagen.flow_from_directory(
    base_dir,
    batch_size=batches,
    target_size=(150,150),
    class_mode="categorical",
    subset="training"
)

#Validation generator
val_im = datagen.flow_from_directory(
    base_dir,
    batch_size=batches,
    target_size=(150,150),
    class_mode="categorical",
    subset="validation",
)


#Test images in numpy array
test_img_path = val_im.filepaths
test_imgs2 = []
for img in test_img_path:
  img_array = imread(img)
  img_resize = resize(img_array, (150,150,3))
  test_imgs2.append(img_resize)
test_imgs2=np.array(test_imgs2)

#True test labels
ytest2 = val_im.classes

#Create model
model4 = MODEL(initializer = "GlorotUniform")

#Compile model
model4.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

epochs = 50

#Train the model
hist_4 = model4.fit(train_im,
                    validation_data=val_im,
                    epochs=epochs,
                    batch_size=batches,
                    verbose=2)

#Model Predictions
pred4 = np.argmax(model4.predict(test_imgs2, verbose=0),axis=1)
# Out:
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Epoch 1/50
# 22/22 - 21s - loss: 3.5737 - accuracy: 0.3125 - val_loss: 2.6354 - val_accuracy: 0.3623 - 21s/epoch - 946ms/step
# Epoch 2/50
# 22/22 - 18s - loss: 2.2012 - accuracy: 0.5015 - val_loss: 1.9543 - val_accuracy: 0.5453 - 18s/epoch - 803ms/step
# Epoch 3/50
# 22/22 - 16s - loss: 1.7712 - accuracy: 0.5685 - val_loss: 1.6786 - val_accuracy: 0.5592 - 16s/epoch - 743ms/step
# Epoch 4/50
# 22/22 - 16s - loss: 1.5842 - accuracy: 0.5869 - val_loss: 1.5205 - val_accuracy: 0.6063 - 16s/epoch - 743ms/step
# Epoch 5/50
# 22/22 - 16s - loss: 1.4808 - accuracy: 0.6085 - val_loss: 1.4551 - val_accuracy: 0.6152 - 16s/epoch - 743ms/step
# Epoch 6/50
# 22/22 - 16s - loss: 1.4049 - accuracy: 0.6199 - val_loss: 1.3847 - val_accuracy: 0.6255 - 16s/epoch - 744ms/step
# Epoch 7/50
# 22/22 - 16s - loss: 1.3631 - accuracy: 0.6248 - val_loss: 1.3436 - val_accuracy: 0.6320 - 16s/epoch - 741ms/step
# Epoch 8/50
# 22/22 - 16s - loss: 1.3162 - accuracy: 0.6393 - val_loss: 1.3508 - val_accuracy: 0.6127 - 16s/epoch - 739ms/step
# Epoch 9/50
# 22/22 - 16s - loss: 1.2804 - accuracy: 0.6524 - val_loss: 1.2506 - val_accuracy: 0.6669 - 16s/epoch - 737ms/step
# Epoch 10/50
# 22/22 - 16s - loss: 1.2481 - accuracy: 0.6590 - val_loss: 1.2739 - val_accuracy: 0.6530 - 16s/epoch - 736ms/step
# Epoch 11/50
# 22/22 - 16s - loss: 1.2412 - accuracy: 0.6565 - val_loss: 1.2196 - val_accuracy: 0.6658 - 16s/epoch - 736ms/step
# Epoch 12/50
# 22/22 - 16s - loss: 1.2019 - accuracy: 0.6687 - val_loss: 1.1692 - val_accuracy: 0.6776 - 16s/epoch - 741ms/step
# Epoch 13/50
# 22/22 - 16s - loss: 1.1758 - accuracy: 0.6793 - val_loss: 1.1710 - val_accuracy: 0.6954 - 16s/epoch - 734ms/step
# Epoch 14/50
# 22/22 - 16s - loss: 1.1511 - accuracy: 0.6850 - val_loss: 1.1329 - val_accuracy: 0.6958 - 16s/epoch - 743ms/step
# Epoch 15/50
# 22/22 - 16s - loss: 1.1740 - accuracy: 0.6736 - val_loss: 1.1880 - val_accuracy: 0.6608 - 16s/epoch - 738ms/step
# Epoch 16/50
# 22/22 - 16s - loss: 1.1305 - accuracy: 0.6949 - val_loss: 1.1160 - val_accuracy: 0.6965 - 16s/epoch - 744ms/step
# Epoch 17/50
# 22/22 - 16s - loss: 1.1188 - accuracy: 0.6946 - val_loss: 1.1432 - val_accuracy: 0.6669 - 16s/epoch - 735ms/step
# Epoch 18/50
# 22/22 - 16s - loss: 1.1022 - accuracy: 0.6999 - val_loss: 1.0765 - val_accuracy: 0.7118 - 16s/epoch - 739ms/step
# Epoch 19/50
# 22/22 - 16s - loss: 1.1018 - accuracy: 0.6975 - val_loss: 1.0952 - val_accuracy: 0.7019 - 16s/epoch - 733ms/step
# Epoch 20/50
# 22/22 - 16s - loss: 1.0881 - accuracy: 0.7072 - val_loss: 1.0978 - val_accuracy: 0.7108 - 16s/epoch - 745ms/step
# Epoch 21/50
# 22/22 - 18s - loss: 1.0682 - accuracy: 0.7085 - val_loss: 1.0513 - val_accuracy: 0.7136 - 18s/epoch - 802ms/step
# Epoch 22/50
# 22/22 - 17s - loss: 1.0796 - accuracy: 0.7037 - val_loss: 1.0811 - val_accuracy: 0.7015 - 17s/epoch - 790ms/step
# Epoch 23/50
# 22/22 - 17s - loss: 1.0876 - accuracy: 0.7028 - val_loss: 1.0351 - val_accuracy: 0.7322 - 17s/epoch - 786ms/step
# Epoch 24/50
# 22/22 - 17s - loss: 1.0317 - accuracy: 0.7304 - val_loss: 1.0367 - val_accuracy: 0.7183 - 17s/epoch - 789ms/step
# Epoch 25/50
# 22/22 - 17s - loss: 1.0222 - accuracy: 0.7276 - val_loss: 1.0384 - val_accuracy: 0.7168 - 17s/epoch - 784ms/step
# Epoch 26/50
# 22/22 - 17s - loss: 1.0269 - accuracy: 0.7244 - val_loss: 1.0112 - val_accuracy: 0.7354 - 17s/epoch - 775ms/step
# Epoch 27/50
# 22/22 - 17s - loss: 0.9937 - accuracy: 0.7411 - val_loss: 0.9860 - val_accuracy: 0.7529 - 17s/epoch - 784ms/step
# Epoch 28/50
# 22/22 - 17s - loss: 1.0149 - accuracy: 0.7252 - val_loss: 0.9855 - val_accuracy: 0.7507 - 17s/epoch - 791ms/step
# Epoch 29/50
# 22/22 - 17s - loss: 0.9951 - accuracy: 0.7455 - val_loss: 1.0374 - val_accuracy: 0.7229 - 17s/epoch - 787ms/step
# Epoch 30/50
# 22/22 - 17s - loss: 1.0026 - accuracy: 0.7371 - val_loss: 0.9649 - val_accuracy: 0.7553 - 17s/epoch - 788ms/step
# Epoch 31/50
# 22/22 - 17s - loss: 0.9732 - accuracy: 0.7489 - val_loss: 1.0173 - val_accuracy: 0.7161 - 17s/epoch - 786ms/step
# Epoch 32/50
# 22/22 - 17s - loss: 0.9609 - accuracy: 0.7520 - val_loss: 0.9625 - val_accuracy: 0.7539 - 17s/epoch - 784ms/step
# Epoch 33/50
# 22/22 - 17s - loss: 0.9597 - accuracy: 0.7516 - val_loss: 0.9424 - val_accuracy: 0.7593 - 17s/epoch - 781ms/step
# Epoch 34/50
# 22/22 - 17s - loss: 0.9629 - accuracy: 0.7533 - val_loss: 0.9592 - val_accuracy: 0.7636 - 17s/epoch - 784ms/step
# Epoch 35/50
# 22/22 - 17s - loss: 0.9687 - accuracy: 0.7502 - val_loss: 0.9479 - val_accuracy: 0.7678 - 17s/epoch - 780ms/step
# Epoch 36/50
# 22/22 - 17s - loss: 0.9612 - accuracy: 0.7538 - val_loss: 0.9698 - val_accuracy: 0.7550 - 17s/epoch - 782ms/step
# Epoch 37/50
# 22/22 - 17s - loss: 0.9615 - accuracy: 0.7516 - val_loss: 0.9466 - val_accuracy: 0.7571 - 17s/epoch - 783ms/step
# Epoch 38/50
# 22/22 - 17s - loss: 0.9517 - accuracy: 0.7519 - val_loss: 0.9745 - val_accuracy: 0.7504 - 17s/epoch - 779ms/step
# Epoch 39/50
# 22/22 - 17s - loss: 0.9421 - accuracy: 0.7572 - val_loss: 0.9409 - val_accuracy: 0.7721 - 17s/epoch - 780ms/step
# Epoch 40/50
# 22/22 - 17s - loss: 0.9683 - accuracy: 0.7451 - val_loss: 0.9558 - val_accuracy: 0.7685 - 17s/epoch - 779ms/step
# Epoch 41/50
# 22/22 - 17s - loss: 0.9491 - accuracy: 0.7590 - val_loss: 0.9802 - val_accuracy: 0.7422 - 17s/epoch - 779ms/step
# Epoch 42/50
# 22/22 - 17s - loss: 0.9414 - accuracy: 0.7541 - val_loss: 0.9228 - val_accuracy: 0.7689 - 17s/epoch - 775ms/step
# Epoch 43/50
# 22/22 - 17s - loss: 0.9367 - accuracy: 0.7600 - val_loss: 0.9435 - val_accuracy: 0.7568 - 17s/epoch - 776ms/step
# Epoch 44/50
# 22/22 - 17s - loss: 0.9318 - accuracy: 0.7586 - val_loss: 0.9068 - val_accuracy: 0.7753 - 17s/epoch - 784ms/step
# Epoch 45/50
# 22/22 - 17s - loss: 0.9306 - accuracy: 0.7620 - val_loss: 0.9308 - val_accuracy: 0.7625 - 17s/epoch - 774ms/step
# Epoch 46/50
# 22/22 - 17s - loss: 0.9149 - accuracy: 0.7670 - val_loss: 0.8958 - val_accuracy: 0.7817 - 17s/epoch - 785ms/step
# Epoch 47/50
# 22/22 - 17s - loss: 0.9147 - accuracy: 0.7660 - val_loss: 0.9079 - val_accuracy: 0.7800 - 17s/epoch - 777ms/step
# Epoch 48/50
# 22/22 - 17s - loss: 0.9215 - accuracy: 0.7626 - val_loss: 0.9674 - val_accuracy: 0.7550 - 17s/epoch - 781ms/step
# Epoch 49/50
# 22/22 - 17s - loss: 0.8973 - accuracy: 0.7728 - val_loss: 0.8836 - val_accuracy: 0.7899 - 17s/epoch - 784ms/step
# Epoch 50/50
# 22/22 - 17s - loss: 0.8847 - accuracy: 0.7789 - val_loss: 0.8879 - val_accuracy: 0.7839 - 17s/epoch - 781ms/step

# %% [markdown]
# ##Loss and Accuracy Plot

# %%
acc4 = hist_4.history['accuracy']
val_acc4 = hist_4.history['val_accuracy']
loss4 = hist_4.history['loss']
val_loss4 = hist_4.history['val_loss']

epochs = range(len(acc4))

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, acc4, label='Training accuracy')
plt.plot(epochs, val_acc4, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(["Train", "Val"])

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, loss4, label='Training Loss')
plt.plot(epochs, val_loss4, label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(["Train", "Val"]);

# %% [markdown]
# ##Confusion matrix and classification report

# %%
conf_clf(ytest2, pred4)
# Out:
#               precision    recall  f1-score   support
#
#    Buildings       0.78      0.75      0.76       438
#       Forest       0.92      0.94      0.93       454
#      Glacier       0.74      0.77      0.76       480
#     Mountain       0.76      0.64      0.70       502
#          Sea       0.68      0.82      0.75       454
#       Street       0.83      0.79      0.81       476
#
#     accuracy                           0.78      2804
#    macro avg       0.79      0.79      0.78      2804
# weighted avg       0.79      0.78      0.78      2804

# %% [markdown]
# #Comparison

# %% [markdown]
# ##Learning curves

# %%
plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, val_acc1, label='Baseline')
plt.plot(epochs, val_acc2, label='Weights init')
plt.plot(epochs, val_acc3, label='Learning rate')
plt.plot(epochs, val_acc4, label='Batch size')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy Comparison")
plt.legend();

plt.figure(figsize=(10,6), dpi=80)
plt.plot(epochs, val_loss1, label='Baseline')
plt.plot(epochs, val_loss2, label='Weights init')
plt.plot(epochs, val_loss3, label='Learning rate')
plt.plot(epochs, val_loss4, label='Batch size')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Comparison")
plt.legend();

# %% [markdown]
# ##Each Trick Accuracy

# %%
baseline = 71
weightI = 73
learR = 75
batchS = 78

x = np.arange(4)
y1 = [baseline, weightI, learR, batchS]

width = 0.4

sns.set_theme(style='whitegrid', palette='Dark2')
plt.figure(figsize=(8,6), dpi=100)
plt.bar(x, y1, width, color=['C0','C1','C2','C3'])
plt.xlabel("Tricks")
plt.ylabel("Accuracy (%)")
plt.title('Accuracies of each trick')
plt.xticks(x, ['Baseline', 'Weights Init', 'LearningR', 'Batch Size']);
