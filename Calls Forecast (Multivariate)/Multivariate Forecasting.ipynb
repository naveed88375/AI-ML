# %% [markdown]
# #Libraries Import

# %%
# %%capture
# !pip install openpyxl==3.0.5
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from matplotlib import pyplot as plt
import seaborn as sns
from google.colab import files

# %% [markdown]
# #Get Dataset

# %%
#Uncomment below line if using Colab
files.upload()

df = pd.read_excel('Data_set_v4.5.xlsx')      #Read CSV data file

df = df.drop(["Factor4_Macro_Economic"], axis=1)

# %% [markdown]
# #Data Visualization

# %%
#Visualization
sns.set_theme()
plt.figure(figsize=(15,8), dpi=100)
plt.plot(df["Date"][:1673], df["No_calls_Offered"][:1673])
plt.xlabel("Days")
plt.ylabel("Calls Volume")
plt.title("Calls Volume Data")
# Out:
# Text(0.5, 1.0, 'Calls Volume Data')

# %% [markdown]
# #Data Preprocessing
# ##Categorical to Numeric Conversion

# %%
#Store the keys for each category
week_day= {'Sunday':0, 'Monday':1,'Tuesday':1,'Wednesday':1,'Thursday':1,'Friday':1,'Saturday':0}
holiday= {'holiday':0, 'no-holiday':1}
df = df.drop(["Factor3_Three-period_moving_average_the_trend","Factor4_seasonality"], axis=1)
weather = {'Cloudy':1, '\tCloudy':1, 'Fair':2, 'Partly Cloudy':1, 'Windy':3,
       'Light Rain':4, 'Mostly Cloudy':1, 'Haze':5, '\tLight Rain':4, 'Mist':5,
       'Rain':4, 'Fog':5, 'Smoke':5, 'Heavy Rain':4, 'Fair ':2, 'Smoke\n':5,
       'Mostly Cloudy ':1, 'Cloudy ':1, 'Partly Cloudy ':1}

#Replace the categorical data with the keys
df['Factor1_Day_of_week']= df['Factor1_Day_of_week'].map(week_day)
df['Factor2_Holidays']= df['Factor2_Holidays'].map(holiday)
df['Factor5_Weather_trends']= df['Factor5_Weather_trends'].map(weather)

#Store the dates in separate variable
Dates = pd.to_datetime(df['Date'])
Dates = Dates[:1673]

#Getting the data
data_cols = list(df)[1:5]

#Getting training data
df_train = df[data_cols].astype(float)

# %% [markdown]
# #Feature Scaling

# %%
#Declare the scaler object
scaler = StandardScaler()
#Fit the object to the data
scaler = scaler.fit(df_train)
#Transform the data
df_scaled = pd.DataFrame(scaler.transform(df_train), columns = data_cols)
#Get scaled training data
df_train_scaled=df_scaled[:1673].to_numpy()
#Get features for future prediction
f_factors = df_scaled[1673:].to_numpy()
#Separate Training and future testing data
df = df[:1673]
df_train = df_train[:1673]
df_scaled = df_scaled[:1673]

# %% [markdown]
# ##Data Preparation for Multivariate Forecasting

# %%
#Declare training and testing arrays
X_train = []
y_train = []
#Value prediction in future
future_value = 1
#Feature window size 
window_size = 14

#For loop over the timeseries data for conversion into windows
for i in range(window_size, len(df_train_scaled) - future_value +1):
    X_train.append(df_train_scaled[i - window_size:i, 0:df_train.shape[1]])
    y_train.append(df_train_scaled[i + future_value - 1:i + future_value, 0])

#Convert to numpy array
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# #Long Short Term Memory (LSTM) Model Design

# %%
#Keras sequential Class
model = Sequential()
#Model layers
model.add(LSTM(64, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dense(y_train.shape[1]))

#Model compilation
model.compile(optimizer='adam', loss='mae')

# Model Training
history = model.fit(X_train, y_train, epochs=500, batch_size=16, verbose=2)
# Out:
# Epoch 1/500
# 104/104 - 12s - loss: 0.7198 - 12s/epoch - 118ms/step
# Epoch 2/500
# 104/104 - 8s - loss: 0.5366 - 8s/epoch - 80ms/step
# Epoch 3/500
# 104/104 - 8s - loss: 0.3378 - 8s/epoch - 82ms/step
# Epoch 4/500
# 104/104 - 8s - loss: 0.2461 - 8s/epoch - 80ms/step
# Epoch 5/500
# 104/104 - 8s - loss: 0.2216 - 8s/epoch - 80ms/step
# Epoch 6/500
# 104/104 - 8s - loss: 0.2120 - 8s/epoch - 81ms/step
# Epoch 7/500
# 104/104 - 8s - loss: 0.2207 - 8s/epoch - 79ms/step
# Epoch 8/500
# 104/104 - 8s - loss: 0.2057 - 8s/epoch - 78ms/step
# Epoch 9/500
# 104/104 - 8s - loss: 0.2043 - 8s/epoch - 81ms/step
# Epoch 10/500
# 104/104 - 10s - loss: 0.2034 - 10s/epoch - 92ms/step
# Epoch 11/500
# 104/104 - 8s - loss: 0.2045 - 8s/epoch - 79ms/step
# Epoch 12/500
# 104/104 - 8s - loss: 0.1999 - 8s/epoch - 79ms/step
# Epoch 13/500
# 104/104 - 8s - loss: 0.1985 - 8s/epoch - 80ms/step
# Epoch 14/500
# 104/104 - 8s - loss: 0.1914 - 8s/epoch - 79ms/step
# Epoch 15/500
# 104/104 - 8s - loss: 0.1909 - 8s/epoch - 80ms/step
# Epoch 16/500
# 104/104 - 9s - loss: 0.1893 - 9s/epoch - 83ms/step
# Epoch 17/500
# 104/104 - 8s - loss: 0.1888 - 8s/epoch - 82ms/step
# Epoch 18/500
# 104/104 - 8s - loss: 0.1903 - 8s/epoch - 81ms/step
# Epoch 19/500
# 104/104 - 8s - loss: 0.1865 - 8s/epoch - 80ms/step
# Epoch 20/500
# 104/104 - 8s - loss: 0.1835 - 8s/epoch - 79ms/step
# Epoch 21/500
# 104/104 - 12s - loss: 0.1842 - 12s/epoch - 115ms/step
# Epoch 22/500
# 104/104 - 19s - loss: 0.1839 - 19s/epoch - 185ms/step
# Epoch 23/500
# 104/104 - 8s - loss: 0.1774 - 8s/epoch - 81ms/step
# Epoch 24/500
# 104/104 - 8s - loss: 0.1831 - 8s/epoch - 82ms/step
# Epoch 25/500
# 104/104 - 8s - loss: 0.1782 - 8s/epoch - 80ms/step
# Epoch 26/500
# 104/104 - 9s - loss: 0.1767 - 9s/epoch - 82ms/step
# Epoch 27/500
# 104/104 - 8s - loss: 0.1750 - 8s/epoch - 81ms/step
# Epoch 28/500
# 104/104 - 8s - loss: 0.1746 - 8s/epoch - 80ms/step
# Epoch 29/500
# 104/104 - 8s - loss: 0.1723 - 8s/epoch - 81ms/step
# Epoch 30/500
# 104/104 - 8s - loss: 0.1681 - 8s/epoch - 80ms/step
# Epoch 31/500
# 104/104 - 8s - loss: 0.1650 - 8s/epoch - 81ms/step
# Epoch 32/500
# 104/104 - 8s - loss: 0.1666 - 8s/epoch - 81ms/step
# Epoch 33/500
# 104/104 - 8s - loss: 0.1615 - 8s/epoch - 80ms/step
# Epoch 34/500
# 104/104 - 8s - loss: 0.1678 - 8s/epoch - 80ms/step
# Epoch 35/500
# 104/104 - 9s - loss: 0.1644 - 9s/epoch - 82ms/step
# Epoch 36/500
# 104/104 - 8s - loss: 0.1622 - 8s/epoch - 79ms/step
# Epoch 37/500
# 104/104 - 8s - loss: 0.1599 - 8s/epoch - 80ms/step
# Epoch 38/500
# 104/104 - 8s - loss: 0.1628 - 8s/epoch - 81ms/step
# Epoch 39/500
# 104/104 - 9s - loss: 0.1557 - 9s/epoch - 82ms/step
# Epoch 40/500
# 104/104 - 8s - loss: 0.1614 - 8s/epoch - 80ms/step
# Epoch 41/500
# 104/104 - 8s - loss: 0.1584 - 8s/epoch - 81ms/step
# Epoch 42/500
# 104/104 - 8s - loss: 0.1514 - 8s/epoch - 81ms/step
# Epoch 43/500
# 104/104 - 8s - loss: 0.1523 - 8s/epoch - 80ms/step
# Epoch 44/500
# 104/104 - 8s - loss: 0.1546 - 8s/epoch - 80ms/step
# Epoch 45/500
# 104/104 - 8s - loss: 0.1525 - 8s/epoch - 81ms/step
# Epoch 46/500
# 104/104 - 8s - loss: 0.1546 - 8s/epoch - 81ms/step
# Epoch 47/500
# 104/104 - 8s - loss: 0.1485 - 8s/epoch - 81ms/step
# Epoch 48/500
# 104/104 - 8s - loss: 0.1526 - 8s/epoch - 80ms/step
# Epoch 49/500
# 104/104 - 8s - loss: 0.1509 - 8s/epoch - 81ms/step
# Epoch 50/500
# 104/104 - 8s - loss: 0.1475 - 8s/epoch - 80ms/step
# Epoch 51/500
# 104/104 - 8s - loss: 0.1437 - 8s/epoch - 81ms/step
# Epoch 52/500
# 104/104 - 8s - loss: 0.1471 - 8s/epoch - 81ms/step
# Epoch 53/500
# 104/104 - 9s - loss: 0.1431 - 9s/epoch - 82ms/step
# Epoch 54/500
# 104/104 - 8s - loss: 0.1408 - 8s/epoch - 82ms/step
# Epoch 55/500
# 104/104 - 9s - loss: 0.1430 - 9s/epoch - 83ms/step
# Epoch 56/500
# 104/104 - 8s - loss: 0.1398 - 8s/epoch - 80ms/step
# Epoch 57/500
# 104/104 - 8s - loss: 0.1417 - 8s/epoch - 81ms/step
# Epoch 58/500
# 104/104 - 8s - loss: 0.1435 - 8s/epoch - 81ms/step
# Epoch 59/500
# 104/104 - 9s - loss: 0.1382 - 9s/epoch - 82ms/step
# Epoch 60/500
# 104/104 - 8s - loss: 0.1383 - 8s/epoch - 80ms/step
# Epoch 61/500
# 104/104 - 8s - loss: 0.1390 - 8s/epoch - 81ms/step
# Epoch 62/500
# 104/104 - 9s - loss: 0.1389 - 9s/epoch - 82ms/step
# Epoch 63/500
# 104/104 - 8s - loss: 0.1404 - 8s/epoch - 80ms/step
# Epoch 64/500
# 104/104 - 9s - loss: 0.1328 - 9s/epoch - 82ms/step
# Epoch 65/500
# 104/104 - 8s - loss: 0.1327 - 8s/epoch - 80ms/step
# Epoch 66/500
# 104/104 - 8s - loss: 0.1330 - 8s/epoch - 80ms/step
# Epoch 67/500
# 104/104 - 8s - loss: 0.1297 - 8s/epoch - 81ms/step
# Epoch 68/500
# 104/104 - 8s - loss: 0.1329 - 8s/epoch - 80ms/step
# Epoch 69/500
# 104/104 - 8s - loss: 0.1286 - 8s/epoch - 80ms/step
# Epoch 70/500
# 104/104 - 8s - loss: 0.1327 - 8s/epoch - 81ms/step
# Epoch 71/500
# 104/104 - 8s - loss: 0.1265 - 8s/epoch - 81ms/step
# Epoch 72/500
# 104/104 - 9s - loss: 0.1292 - 9s/epoch - 82ms/step
# Epoch 73/500
# 104/104 - 8s - loss: 0.1276 - 8s/epoch - 81ms/step
# Epoch 74/500
# 104/104 - 9s - loss: 0.1320 - 9s/epoch - 83ms/step
# Epoch 75/500
# 104/104 - 8s - loss: 0.1283 - 8s/epoch - 81ms/step
# Epoch 76/500
# 104/104 - 9s - loss: 0.1231 - 9s/epoch - 83ms/step
# Epoch 77/500
# 104/104 - 9s - loss: 0.1231 - 9s/epoch - 82ms/step
# Epoch 78/500
# 104/104 - 8s - loss: 0.1262 - 8s/epoch - 81ms/step
# Epoch 79/500
# 104/104 - 9s - loss: 0.1237 - 9s/epoch - 82ms/step
# Epoch 80/500
# 104/104 - 8s - loss: 0.1280 - 8s/epoch - 82ms/step
# Epoch 81/500
# 104/104 - 9s - loss: 0.1235 - 9s/epoch - 82ms/step
# Epoch 82/500
# 104/104 - 8s - loss: 0.1204 - 8s/epoch - 82ms/step
# Epoch 83/500
# 104/104 - 9s - loss: 0.1207 - 9s/epoch - 82ms/step
# Epoch 84/500
# 104/104 - 8s - loss: 0.1212 - 8s/epoch - 80ms/step
# Epoch 85/500
# 104/104 - 9s - loss: 0.1188 - 9s/epoch - 82ms/step
# Epoch 86/500
# 104/104 - 8s - loss: 0.1162 - 8s/epoch - 81ms/step
# Epoch 87/500
# 104/104 - 8s - loss: 0.1206 - 8s/epoch - 80ms/step
# Epoch 88/500
# 104/104 - 9s - loss: 0.1173 - 9s/epoch - 82ms/step
# Epoch 89/500
# 104/104 - 8s - loss: 0.1217 - 8s/epoch - 81ms/step
# Epoch 90/500
# 104/104 - 8s - loss: 0.1138 - 8s/epoch - 80ms/step
# Epoch 91/500
# 104/104 - 8s - loss: 0.1141 - 8s/epoch - 81ms/step
# Epoch 92/500
# 104/104 - 8s - loss: 0.1123 - 8s/epoch - 79ms/step
# Epoch 93/500
# 104/104 - 8s - loss: 0.1126 - 8s/epoch - 79ms/step
# Epoch 94/500
# 104/104 - 8s - loss: 0.1139 - 8s/epoch - 79ms/step
# Epoch 95/500
# 104/104 - 8s - loss: 0.1111 - 8s/epoch - 80ms/step
# Epoch 96/500
# 104/104 - 8s - loss: 0.1099 - 8s/epoch - 81ms/step
# Epoch 97/500
# 104/104 - 9s - loss: 0.1109 - 9s/epoch - 82ms/step
# Epoch 98/500
# 104/104 - 8s - loss: 0.1094 - 8s/epoch - 81ms/step
# Epoch 99/500
# 104/104 - 8s - loss: 0.1070 - 8s/epoch - 78ms/step
# Epoch 100/500
# 104/104 - 8s - loss: 0.1093 - 8s/epoch - 79ms/step
# Epoch 101/500
# 104/104 - 8s - loss: 0.1086 - 8s/epoch - 81ms/step
# Epoch 102/500
# 104/104 - 8s - loss: 0.1070 - 8s/epoch - 80ms/step
# Epoch 103/500
# 104/104 - 8s - loss: 0.1036 - 8s/epoch - 79ms/step
# Epoch 104/500
# 104/104 - 8s - loss: 0.1008 - 8s/epoch - 80ms/step
# Epoch 105/500
# 104/104 - 8s - loss: 0.1039 - 8s/epoch - 80ms/step
# Epoch 106/500
# 104/104 - 8s - loss: 0.1009 - 8s/epoch - 81ms/step
# Epoch 107/500
# 104/104 - 8s - loss: 0.1044 - 8s/epoch - 79ms/step
# Epoch 108/500
# 104/104 - 8s - loss: 0.1032 - 8s/epoch - 79ms/step
# Epoch 109/500
# 104/104 - 8s - loss: 0.1048 - 8s/epoch - 79ms/step
# Epoch 110/500
# 104/104 - 8s - loss: 0.0998 - 8s/epoch - 81ms/step
# Epoch 111/500
# 104/104 - 8s - loss: 0.0987 - 8s/epoch - 79ms/step
# Epoch 112/500
# 104/104 - 8s - loss: 0.1019 - 8s/epoch - 79ms/step
# Epoch 113/500
# 104/104 - 9s - loss: 0.0969 - 9s/epoch - 83ms/step
# Epoch 114/500
# 104/104 - 8s - loss: 0.0993 - 8s/epoch - 81ms/step
# Epoch 115/500
# 104/104 - 9s - loss: 0.0968 - 9s/epoch - 82ms/step
# Epoch 116/500
# 104/104 - 8s - loss: 0.0979 - 8s/epoch - 79ms/step
# Epoch 117/500
# 104/104 - 8s - loss: 0.0960 - 8s/epoch - 80ms/step
# Epoch 118/500
# 104/104 - 8s - loss: 0.0981 - 8s/epoch - 81ms/step
# Epoch 119/500
# 104/104 - 8s - loss: 0.0935 - 8s/epoch - 79ms/step
# Epoch 120/500
# 104/104 - 8s - loss: 0.0950 - 8s/epoch - 79ms/step
# Epoch 121/500
# 104/104 - 8s - loss: 0.0945 - 8s/epoch - 79ms/step
# Epoch 122/500
# 104/104 - 8s - loss: 0.0900 - 8s/epoch - 81ms/step
# Epoch 123/500
# 104/104 - 8s - loss: 0.0926 - 8s/epoch - 80ms/step
# Epoch 124/500
# 104/104 - 9s - loss: 0.0905 - 9s/epoch - 82ms/step
# Epoch 125/500
# 104/104 - 9s - loss: 0.0912 - 9s/epoch - 82ms/step
# Epoch 126/500
# 104/104 - 9s - loss: 0.0962 - 9s/epoch - 83ms/step
# Epoch 127/500
# 104/104 - 8s - loss: 0.0912 - 8s/epoch - 80ms/step
# Epoch 128/500
# 104/104 - 8s - loss: 0.0863 - 8s/epoch - 78ms/step
# Epoch 129/500
# 104/104 - 8s - loss: 0.0865 - 8s/epoch - 78ms/step
# Epoch 130/500
# 104/104 - 8s - loss: 0.0860 - 8s/epoch - 78ms/step
# Epoch 131/500
# 104/104 - 8s - loss: 0.0867 - 8s/epoch - 78ms/step
# Epoch 132/500
# 104/104 - 8s - loss: 0.0839 - 8s/epoch - 79ms/step
# Epoch 133/500
# 104/104 - 8s - loss: 0.0825 - 8s/epoch - 78ms/step
# Epoch 134/500
# 104/104 - 8s - loss: 0.0819 - 8s/epoch - 80ms/step
# Epoch 135/500
# 104/104 - 8s - loss: 0.0835 - 8s/epoch - 77ms/step
# Epoch 136/500
# 104/104 - 8s - loss: 0.0812 - 8s/epoch - 76ms/step
# Epoch 137/500
# 104/104 - 8s - loss: 0.0784 - 8s/epoch - 78ms/step
# Epoch 138/500
# 104/104 - 8s - loss: 0.0841 - 8s/epoch - 78ms/step
# Epoch 139/500
# 104/104 - 8s - loss: 0.0810 - 8s/epoch - 78ms/step
# Epoch 140/500
# 104/104 - 8s - loss: 0.0830 - 8s/epoch - 79ms/step
# Epoch 141/500
# 104/104 - 8s - loss: 0.0805 - 8s/epoch - 78ms/step
# Epoch 142/500
# 104/104 - 8s - loss: 0.0750 - 8s/epoch - 78ms/step
# Epoch 143/500
# 104/104 - 8s - loss: 0.0816 - 8s/epoch - 77ms/step
# Epoch 144/500
# 104/104 - 8s - loss: 0.0766 - 8s/epoch - 76ms/step
# Epoch 145/500
# 104/104 - 8s - loss: 0.0768 - 8s/epoch - 78ms/step
# Epoch 146/500
# 104/104 - 8s - loss: 0.0746 - 8s/epoch - 77ms/step
# Epoch 147/500
# 104/104 - 8s - loss: 0.0776 - 8s/epoch - 77ms/step
# Epoch 148/500
# 104/104 - 8s - loss: 0.0756 - 8s/epoch - 77ms/step
# Epoch 149/500
# 104/104 - 8s - loss: 0.0737 - 8s/epoch - 77ms/step
# Epoch 150/500
# 104/104 - 8s - loss: 0.0755 - 8s/epoch - 79ms/step
# Epoch 151/500
# 104/104 - 8s - loss: 0.0757 - 8s/epoch - 78ms/step
# Epoch 152/500
# 104/104 - 8s - loss: 0.0712 - 8s/epoch - 81ms/step
# Epoch 153/500
# 104/104 - 8s - loss: 0.0739 - 8s/epoch - 78ms/step
# Epoch 154/500
# 104/104 - 8s - loss: 0.0740 - 8s/epoch - 78ms/step
# Epoch 155/500
# 104/104 - 8s - loss: 0.0703 - 8s/epoch - 77ms/step
# Epoch 156/500
# 104/104 - 8s - loss: 0.0694 - 8s/epoch - 79ms/step
# Epoch 157/500
# 104/104 - 8s - loss: 0.0687 - 8s/epoch - 77ms/step
# Epoch 158/500
# 104/104 - 8s - loss: 0.0671 - 8s/epoch - 77ms/step
# Epoch 159/500
# 104/104 - 8s - loss: 0.0695 - 8s/epoch - 79ms/step
# Epoch 160/500
# 104/104 - 8s - loss: 0.0693 - 8s/epoch - 76ms/step
# Epoch 161/500
# 104/104 - 8s - loss: 0.0680 - 8s/epoch - 77ms/step
# Epoch 162/500
# 104/104 - 8s - loss: 0.0666 - 8s/epoch - 77ms/step
# Epoch 163/500
# 104/104 - 8s - loss: 0.0658 - 8s/epoch - 79ms/step
# Epoch 164/500
# 104/104 - 8s - loss: 0.0633 - 8s/epoch - 77ms/step
# Epoch 165/500
# 104/104 - 8s - loss: 0.0676 - 8s/epoch - 79ms/step
# Epoch 166/500
# 104/104 - 8s - loss: 0.0642 - 8s/epoch - 80ms/step
# Epoch 167/500
# 104/104 - 8s - loss: 0.0664 - 8s/epoch - 77ms/step
# Epoch 168/500
# 104/104 - 8s - loss: 0.0650 - 8s/epoch - 77ms/step
# Epoch 169/500
# 104/104 - 8s - loss: 0.0631 - 8s/epoch - 77ms/step
# Epoch 170/500
# 104/104 - 8s - loss: 0.0636 - 8s/epoch - 79ms/step
# Epoch 171/500
# 104/104 - 8s - loss: 0.0620 - 8s/epoch - 77ms/step
# Epoch 172/500
# 104/104 - 8s - loss: 0.0593 - 8s/epoch - 76ms/step
# Epoch 173/500
# 104/104 - 8s - loss: 0.0608 - 8s/epoch - 78ms/step
# Epoch 174/500
# 104/104 - 8s - loss: 0.0602 - 8s/epoch - 77ms/step
# Epoch 175/500
# 104/104 - 8s - loss: 0.0588 - 8s/epoch - 80ms/step
# Epoch 176/500
# 104/104 - 8s - loss: 0.0580 - 8s/epoch - 80ms/step
# Epoch 177/500
# 104/104 - 8s - loss: 0.0601 - 8s/epoch - 80ms/step
# Epoch 178/500
# 104/104 - 8s - loss: 0.0597 - 8s/epoch - 77ms/step
# Epoch 179/500
# 104/104 - 8s - loss: 0.0621 - 8s/epoch - 78ms/step
# Epoch 180/500
# 104/104 - 8s - loss: 0.0589 - 8s/epoch - 78ms/step
# Epoch 181/500
# 104/104 - 8s - loss: 0.0560 - 8s/epoch - 79ms/step
# Epoch 182/500
# 104/104 - 8s - loss: 0.0569 - 8s/epoch - 78ms/step
# Epoch 183/500
# 104/104 - 8s - loss: 0.0550 - 8s/epoch - 78ms/step
# Epoch 184/500
# 104/104 - 8s - loss: 0.0571 - 8s/epoch - 78ms/step
# Epoch 185/500
# 104/104 - 8s - loss: 0.0581 - 8s/epoch - 79ms/step
# Epoch 186/500
# 104/104 - 8s - loss: 0.0560 - 8s/epoch - 79ms/step
# Epoch 187/500
# 104/104 - 8s - loss: 0.0542 - 8s/epoch - 78ms/step
# Epoch 188/500
# 104/104 - 8s - loss: 0.0554 - 8s/epoch - 78ms/step
# Epoch 189/500
# 104/104 - 8s - loss: 0.0530 - 8s/epoch - 78ms/step
# Epoch 190/500
# 104/104 - 8s - loss: 0.0537 - 8s/epoch - 80ms/step
# Epoch 191/500
# 104/104 - 8s - loss: 0.0552 - 8s/epoch - 80ms/step
# Epoch 192/500
# 104/104 - 8s - loss: 0.0531 - 8s/epoch - 78ms/step
# Epoch 193/500
# 104/104 - 8s - loss: 0.0516 - 8s/epoch - 79ms/step
# Epoch 194/500
# 104/104 - 8s - loss: 0.0537 - 8s/epoch - 77ms/step
# Epoch 195/500
# 104/104 - 8s - loss: 0.0518 - 8s/epoch - 79ms/step
# Epoch 196/500
# 104/104 - 8s - loss: 0.0512 - 8s/epoch - 77ms/step
# Epoch 197/500
# 104/104 - 8s - loss: 0.0513 - 8s/epoch - 78ms/step
# Epoch 198/500
# 104/104 - 8s - loss: 0.0536 - 8s/epoch - 78ms/step
# Epoch 199/500
# 104/104 - 8s - loss: 0.0531 - 8s/epoch - 77ms/step
# Epoch 200/500
# 104/104 - 8s - loss: 0.0503 - 8s/epoch - 77ms/step
# Epoch 201/500
# 104/104 - 8s - loss: 0.0483 - 8s/epoch - 78ms/step
# Epoch 202/500
# 104/104 - 8s - loss: 0.0490 - 8s/epoch - 78ms/step
# Epoch 203/500
# 104/104 - 8s - loss: 0.0493 - 8s/epoch - 80ms/step
# Epoch 204/500
# 104/104 - 8s - loss: 0.0481 - 8s/epoch - 77ms/step
# Epoch 205/500
# 104/104 - 8s - loss: 0.0478 - 8s/epoch - 76ms/step
# Epoch 206/500
# 104/104 - 8s - loss: 0.0502 - 8s/epoch - 77ms/step
# Epoch 207/500
# 104/104 - 8s - loss: 0.0479 - 8s/epoch - 77ms/step
# Epoch 208/500
# 104/104 - 8s - loss: 0.0525 - 8s/epoch - 78ms/step
# Epoch 209/500
# 104/104 - 8s - loss: 0.0469 - 8s/epoch - 79ms/step
# Epoch 210/500
# 104/104 - 8s - loss: 0.0446 - 8s/epoch - 79ms/step
# Epoch 211/500
# 104/104 - 8s - loss: 0.0459 - 8s/epoch - 79ms/step
# Epoch 212/500
# 104/104 - 8s - loss: 0.0450 - 8s/epoch - 77ms/step
# Epoch 213/500
# 104/104 - 8s - loss: 0.0472 - 8s/epoch - 78ms/step
# Epoch 214/500
# 104/104 - 8s - loss: 0.0467 - 8s/epoch - 77ms/step
# Epoch 215/500
# 104/104 - 8s - loss: 0.0469 - 8s/epoch - 78ms/step
# Epoch 216/500
# 104/104 - 8s - loss: 0.0430 - 8s/epoch - 78ms/step
# Epoch 217/500
# 104/104 - 8s - loss: 0.0463 - 8s/epoch - 78ms/step
# Epoch 218/500
# 104/104 - 8s - loss: 0.0422 - 8s/epoch - 76ms/step
# Epoch 219/500
# 104/104 - 8s - loss: 0.0444 - 8s/epoch - 79ms/step
# Epoch 220/500
# 104/104 - 8s - loss: 0.0425 - 8s/epoch - 77ms/step
# Epoch 221/500
# 104/104 - 8s - loss: 0.0438 - 8s/epoch - 77ms/step
# Epoch 222/500
# 104/104 - 8s - loss: 0.0405 - 8s/epoch - 77ms/step
# Epoch 223/500
# 104/104 - 8s - loss: 0.0434 - 8s/epoch - 77ms/step
# Epoch 224/500
# 104/104 - 8s - loss: 0.0437 - 8s/epoch - 77ms/step
# Epoch 225/500
# 104/104 - 8s - loss: 0.0454 - 8s/epoch - 79ms/step
# Epoch 226/500
# 104/104 - 8s - loss: 0.0410 - 8s/epoch - 78ms/step
# Epoch 227/500
# 104/104 - 8s - loss: 0.0418 - 8s/epoch - 79ms/step
# Epoch 228/500
# 104/104 - 8s - loss: 0.0439 - 8s/epoch - 78ms/step
# Epoch 229/500
# 104/104 - 8s - loss: 0.0428 - 8s/epoch - 78ms/step
# Epoch 230/500
# 104/104 - 8s - loss: 0.0420 - 8s/epoch - 79ms/step
# Epoch 231/500
# 104/104 - 8s - loss: 0.0409 - 8s/epoch - 79ms/step
# Epoch 232/500
# 104/104 - 8s - loss: 0.0413 - 8s/epoch - 78ms/step
# Epoch 233/500
# 104/104 - 8s - loss: 0.0405 - 8s/epoch - 78ms/step
# Epoch 234/500
# 104/104 - 8s - loss: 0.0417 - 8s/epoch - 77ms/step
# Epoch 235/500
# 104/104 - 8s - loss: 0.0427 - 8s/epoch - 77ms/step
# Epoch 236/500
# 104/104 - 8s - loss: 0.0378 - 8s/epoch - 78ms/step
# Epoch 237/500
# 104/104 - 8s - loss: 0.0412 - 8s/epoch - 77ms/step
# Epoch 238/500
# 104/104 - 8s - loss: 0.0407 - 8s/epoch - 78ms/step
# Epoch 239/500
# 104/104 - 8s - loss: 0.0425 - 8s/epoch - 77ms/step
# Epoch 240/500
# 104/104 - 8s - loss: 0.0377 - 8s/epoch - 77ms/step
# Epoch 241/500
# 104/104 - 8s - loss: 0.0399 - 8s/epoch - 77ms/step
# Epoch 242/500
# 104/104 - 8s - loss: 0.0402 - 8s/epoch - 77ms/step
# Epoch 243/500
# 104/104 - 8s - loss: 0.0411 - 8s/epoch - 78ms/step
# Epoch 244/500
# 104/104 - 8s - loss: 0.0415 - 8s/epoch - 75ms/step
# Epoch 245/500
# 104/104 - 8s - loss: 0.0389 - 8s/epoch - 77ms/step
# Epoch 246/500
# 104/104 - 8s - loss: 0.0364 - 8s/epoch - 76ms/step
# Epoch 247/500
# 104/104 - 8s - loss: 0.0372 - 8s/epoch - 79ms/step
# Epoch 248/500
# 104/104 - 8s - loss: 0.0372 - 8s/epoch - 77ms/step
# Epoch 249/500
# 104/104 - 8s - loss: 0.0357 - 8s/epoch - 75ms/step
# Epoch 250/500
# 104/104 - 8s - loss: 0.0373 - 8s/epoch - 77ms/step
# Epoch 251/500
# 104/104 - 8s - loss: 0.0366 - 8s/epoch - 79ms/step
# Epoch 252/500
# 104/104 - 8s - loss: 0.0386 - 8s/epoch - 77ms/step
# Epoch 253/500
# 104/104 - 8s - loss: 0.0354 - 8s/epoch - 77ms/step
# Epoch 254/500
# 104/104 - 8s - loss: 0.0381 - 8s/epoch - 77ms/step
# Epoch 255/500
# 104/104 - 8s - loss: 0.0351 - 8s/epoch - 77ms/step
# Epoch 256/500
# 104/104 - 8s - loss: 0.0375 - 8s/epoch - 78ms/step
# Epoch 257/500
# 104/104 - 8s - loss: 0.0351 - 8s/epoch - 77ms/step
# Epoch 258/500
# 104/104 - 8s - loss: 0.0334 - 8s/epoch - 76ms/step
# Epoch 259/500
# 104/104 - 8s - loss: 0.0359 - 8s/epoch - 76ms/step
# Epoch 260/500
# 104/104 - 8s - loss: 0.0325 - 8s/epoch - 77ms/step
# Epoch 261/500
# 104/104 - 8s - loss: 0.0354 - 8s/epoch - 76ms/step
# Epoch 262/500
# 104/104 - 8s - loss: 0.0356 - 8s/epoch - 75ms/step
# Epoch 263/500
# 104/104 - 8s - loss: 0.0360 - 8s/epoch - 79ms/step
# Epoch 264/500
# 104/104 - 8s - loss: 0.0341 - 8s/epoch - 78ms/step
# Epoch 265/500
# 104/104 - 8s - loss: 0.0341 - 8s/epoch - 79ms/step
# Epoch 266/500
# 104/104 - 8s - loss: 0.0339 - 8s/epoch - 77ms/step
# Epoch 267/500
# 104/104 - 8s - loss: 0.0350 - 8s/epoch - 76ms/step
# Epoch 268/500
# 104/104 - 8s - loss: 0.0362 - 8s/epoch - 77ms/step
# Epoch 269/500
# 104/104 - 8s - loss: 0.0387 - 8s/epoch - 78ms/step
# Epoch 270/500
# 104/104 - 8s - loss: 0.0366 - 8s/epoch - 77ms/step
# Epoch 271/500
# 104/104 - 8s - loss: 0.0363 - 8s/epoch - 78ms/step
# Epoch 272/500
# 104/104 - 8s - loss: 0.0345 - 8s/epoch - 78ms/step
# Epoch 273/500
# 104/104 - 8s - loss: 0.0325 - 8s/epoch - 78ms/step
# Epoch 274/500
# 104/104 - 8s - loss: 0.0333 - 8s/epoch - 77ms/step
# Epoch 275/500
# 104/104 - 8s - loss: 0.0324 - 8s/epoch - 76ms/step
# Epoch 276/500
# 104/104 - 8s - loss: 0.0331 - 8s/epoch - 77ms/step
# Epoch 277/500
# 104/104 - 8s - loss: 0.0325 - 8s/epoch - 78ms/step
# Epoch 278/500
# 104/104 - 8s - loss: 0.0329 - 8s/epoch - 77ms/step
# Epoch 279/500
# 104/104 - 8s - loss: 0.0337 - 8s/epoch - 78ms/step
# Epoch 280/500
# 104/104 - 8s - loss: 0.0335 - 8s/epoch - 77ms/step
# Epoch 281/500
# 104/104 - 8s - loss: 0.0323 - 8s/epoch - 76ms/step
# Epoch 282/500
# 104/104 - 8s - loss: 0.0329 - 8s/epoch - 78ms/step
# Epoch 283/500
# 104/104 - 8s - loss: 0.0350 - 8s/epoch - 78ms/step
# Epoch 284/500
# 104/104 - 8s - loss: 0.0333 - 8s/epoch - 75ms/step
# Epoch 285/500
# 104/104 - 8s - loss: 0.0325 - 8s/epoch - 76ms/step
# Epoch 286/500
# 104/104 - 8s - loss: 0.0304 - 8s/epoch - 77ms/step
# Epoch 287/500
# 104/104 - 8s - loss: 0.0325 - 8s/epoch - 79ms/step
# Epoch 288/500
# 104/104 - 8s - loss: 0.0333 - 8s/epoch - 78ms/step
# Epoch 289/500
# 104/104 - 8s - loss: 0.0322 - 8s/epoch - 77ms/step
# Epoch 290/500
# 104/104 - 8s - loss: 0.0329 - 8s/epoch - 77ms/step
# Epoch 291/500
# 104/104 - 8s - loss: 0.0342 - 8s/epoch - 77ms/step
# Epoch 292/500
# 104/104 - 8s - loss: 0.0312 - 8s/epoch - 78ms/step
# Epoch 293/500
# 104/104 - 8s - loss: 0.0301 - 8s/epoch - 76ms/step
# Epoch 294/500
# 104/104 - 8s - loss: 0.0327 - 8s/epoch - 76ms/step
# Epoch 295/500
# 104/104 - 8s - loss: 0.0303 - 8s/epoch - 76ms/step
# Epoch 296/500
# 104/104 - 8s - loss: 0.0299 - 8s/epoch - 76ms/step
# Epoch 297/500
# 104/104 - 8s - loss: 0.0308 - 8s/epoch - 77ms/step
# Epoch 298/500
# 104/104 - 8s - loss: 0.0319 - 8s/epoch - 77ms/step
# Epoch 299/500
# 104/104 - 8s - loss: 0.0292 - 8s/epoch - 77ms/step
# Epoch 300/500
# 104/104 - 8s - loss: 0.0321 - 8s/epoch - 77ms/step
# Epoch 301/500
# 104/104 - 8s - loss: 0.0313 - 8s/epoch - 77ms/step
# Epoch 302/500
# 104/104 - 8s - loss: 0.0347 - 8s/epoch - 78ms/step
# Epoch 303/500
# 104/104 - 8s - loss: 0.0330 - 8s/epoch - 75ms/step
# Epoch 304/500
# 104/104 - 8s - loss: 0.0296 - 8s/epoch - 76ms/step
# Epoch 305/500
# 104/104 - 8s - loss: 0.0340 - 8s/epoch - 76ms/step
# Epoch 306/500
# 104/104 - 8s - loss: 0.0293 - 8s/epoch - 78ms/step
# Epoch 307/500
# 104/104 - 8s - loss: 0.0303 - 8s/epoch - 77ms/step
# Epoch 308/500
# 104/104 - 8s - loss: 0.0286 - 8s/epoch - 77ms/step
# Epoch 309/500
# 104/104 - 8s - loss: 0.0298 - 8s/epoch - 75ms/step
# Epoch 310/500
# 104/104 - 8s - loss: 0.0296 - 8s/epoch - 77ms/step
# Epoch 311/500
# 104/104 - 8s - loss: 0.0302 - 8s/epoch - 76ms/step
# Epoch 312/500
# 104/104 - 8s - loss: 0.0274 - 8s/epoch - 78ms/step
# Epoch 313/500
# 104/104 - 8s - loss: 0.0277 - 8s/epoch - 76ms/step
# Epoch 314/500
# 104/104 - 8s - loss: 0.0276 - 8s/epoch - 78ms/step
# Epoch 315/500
# 104/104 - 8s - loss: 0.0314 - 8s/epoch - 80ms/step
# Epoch 316/500
# 104/104 - 8s - loss: 0.0278 - 8s/epoch - 78ms/step
# Epoch 317/500
# 104/104 - 8s - loss: 0.0272 - 8s/epoch - 79ms/step
# Epoch 318/500
# 104/104 - 8s - loss: 0.0308 - 8s/epoch - 78ms/step
# Epoch 319/500
# 104/104 - 8s - loss: 0.0287 - 8s/epoch - 80ms/step
# Epoch 320/500
# 104/104 - 8s - loss: 0.0291 - 8s/epoch - 78ms/step
# Epoch 321/500
# 104/104 - 8s - loss: 0.0304 - 8s/epoch - 77ms/step
# Epoch 322/500
# 104/104 - 8s - loss: 0.0307 - 8s/epoch - 78ms/step
# Epoch 323/500
# 104/104 - 8s - loss: 0.0285 - 8s/epoch - 76ms/step
# Epoch 324/500
# 104/104 - 8s - loss: 0.0320 - 8s/epoch - 77ms/step
# Epoch 325/500
# 104/104 - 8s - loss: 0.0284 - 8s/epoch - 77ms/step
# Epoch 326/500
# 104/104 - 8s - loss: 0.0298 - 8s/epoch - 78ms/step
# Epoch 327/500
# 104/104 - 8s - loss: 0.0286 - 8s/epoch - 77ms/step
# Epoch 328/500
# 104/104 - 8s - loss: 0.0307 - 8s/epoch - 77ms/step
# Epoch 329/500
# 104/104 - 8s - loss: 0.0298 - 8s/epoch - 76ms/step
# Epoch 330/500
# 104/104 - 8s - loss: 0.0290 - 8s/epoch - 76ms/step
# Epoch 331/500
# 104/104 - 8s - loss: 0.0272 - 8s/epoch - 77ms/step
# Epoch 332/500
# 104/104 - 8s - loss: 0.0287 - 8s/epoch - 78ms/step
# Epoch 333/500
# 104/104 - 8s - loss: 0.0270 - 8s/epoch - 77ms/step
# Epoch 334/500
# 104/104 - 8s - loss: 0.0275 - 8s/epoch - 77ms/step
# Epoch 335/500
# 104/104 - 8s - loss: 0.0272 - 8s/epoch - 76ms/step
# Epoch 336/500
# 104/104 - 8s - loss: 0.0293 - 8s/epoch - 76ms/step
# Epoch 337/500
# 104/104 - 8s - loss: 0.0277 - 8s/epoch - 77ms/step
# Epoch 338/500
# 104/104 - 8s - loss: 0.0264 - 8s/epoch - 77ms/step
# Epoch 339/500
# 104/104 - 8s - loss: 0.0279 - 8s/epoch - 78ms/step
# Epoch 340/500
# 104/104 - 8s - loss: 0.0280 - 8s/epoch - 78ms/step
# Epoch 341/500
# 104/104 - 8s - loss: 0.0262 - 8s/epoch - 76ms/step
# Epoch 342/500
# 104/104 - 8s - loss: 0.0260 - 8s/epoch - 77ms/step
# Epoch 343/500
# 104/104 - 8s - loss: 0.0278 - 8s/epoch - 76ms/step
# Epoch 344/500
# 104/104 - 8s - loss: 0.0265 - 8s/epoch - 74ms/step
# Epoch 345/500
# 104/104 - 8s - loss: 0.0266 - 8s/epoch - 77ms/step
# Epoch 346/500
# 104/104 - 8s - loss: 0.0253 - 8s/epoch - 77ms/step
# Epoch 347/500
# 104/104 - 8s - loss: 0.0263 - 8s/epoch - 75ms/step
# Epoch 348/500
# 104/104 - 8s - loss: 0.0271 - 8s/epoch - 76ms/step
# Epoch 349/500
# 104/104 - 8s - loss: 0.0271 - 8s/epoch - 74ms/step
# Epoch 350/500
# 104/104 - 8s - loss: 0.0266 - 8s/epoch - 76ms/step
# Epoch 351/500
# 104/104 - 8s - loss: 0.0254 - 8s/epoch - 76ms/step
# Epoch 352/500
# 104/104 - 8s - loss: 0.0244 - 8s/epoch - 76ms/step
# Epoch 353/500
# 104/104 - 8s - loss: 0.0256 - 8s/epoch - 75ms/step
# Epoch 354/500
# 104/104 - 8s - loss: 0.0273 - 8s/epoch - 77ms/step
# Epoch 355/500
# 104/104 - 8s - loss: 0.0265 - 8s/epoch - 74ms/step
# Epoch 356/500
# 104/104 - 8s - loss: 0.0344 - 8s/epoch - 76ms/step
# Epoch 357/500
# 104/104 - 8s - loss: 0.0325 - 8s/epoch - 76ms/step
# Epoch 358/500
# 104/104 - 8s - loss: 0.0301 - 8s/epoch - 76ms/step
# Epoch 359/500
# 104/104 - 8s - loss: 0.0259 - 8s/epoch - 75ms/step
# Epoch 360/500
# 104/104 - 8s - loss: 0.0260 - 8s/epoch - 76ms/step
# Epoch 361/500
# 104/104 - 8s - loss: 0.0253 - 8s/epoch - 76ms/step
# Epoch 362/500
# 104/104 - 8s - loss: 0.0262 - 8s/epoch - 75ms/step
# Epoch 363/500
# 104/104 - 8s - loss: 0.0236 - 8s/epoch - 76ms/step
# Epoch 364/500
# 104/104 - 8s - loss: 0.0235 - 8s/epoch - 77ms/step
# Epoch 365/500
# 104/104 - 8s - loss: 0.0255 - 8s/epoch - 75ms/step
# Epoch 366/500
# 104/104 - 8s - loss: 0.0257 - 8s/epoch - 75ms/step
# Epoch 367/500
# 104/104 - 8s - loss: 0.0240 - 8s/epoch - 76ms/step
# Epoch 368/500
# 104/104 - 8s - loss: 0.0250 - 8s/epoch - 76ms/step
# Epoch 369/500
# 104/104 - 8s - loss: 0.0262 - 8s/epoch - 75ms/step
# Epoch 370/500
# 104/104 - 8s - loss: 0.0230 - 8s/epoch - 78ms/step
# Epoch 371/500
# 104/104 - 8s - loss: 0.0241 - 8s/epoch - 76ms/step
# Epoch 372/500
# 104/104 - 8s - loss: 0.0227 - 8s/epoch - 76ms/step
# Epoch 373/500
# 104/104 - 8s - loss: 0.0252 - 8s/epoch - 77ms/step
# Epoch 374/500
# 104/104 - 8s - loss: 0.0308 - 8s/epoch - 77ms/step
# Epoch 375/500
# 104/104 - 8s - loss: 0.0242 - 8s/epoch - 77ms/step
# Epoch 376/500
# 104/104 - 8s - loss: 0.0272 - 8s/epoch - 81ms/step
# Epoch 377/500
# 104/104 - 8s - loss: 0.0254 - 8s/epoch - 79ms/step
# Epoch 378/500
# 104/104 - 8s - loss: 0.0248 - 8s/epoch - 81ms/step
# Epoch 379/500
# 104/104 - 8s - loss: 0.0243 - 8s/epoch - 78ms/step
# Epoch 380/500
# 104/104 - 8s - loss: 0.0249 - 8s/epoch - 80ms/step
# Epoch 381/500
# 104/104 - 8s - loss: 0.0236 - 8s/epoch - 80ms/step
# Epoch 382/500
# 104/104 - 8s - loss: 0.0239 - 8s/epoch - 78ms/step
# Epoch 383/500
# 104/104 - 8s - loss: 0.0242 - 8s/epoch - 77ms/step
# Epoch 384/500
# 104/104 - 8s - loss: 0.0229 - 8s/epoch - 76ms/step
# Epoch 385/500
# 104/104 - 8s - loss: 0.0241 - 8s/epoch - 76ms/step
# Epoch 386/500
# 104/104 - 8s - loss: 0.0235 - 8s/epoch - 77ms/step
# Epoch 387/500
# 104/104 - 8s - loss: 0.0232 - 8s/epoch - 78ms/step
# Epoch 388/500
# 104/104 - 8s - loss: 0.0229 - 8s/epoch - 79ms/step
# Epoch 389/500
# 104/104 - 8s - loss: 0.0218 - 8s/epoch - 78ms/step
# Epoch 390/500
# 104/104 - 8s - loss: 0.0244 - 8s/epoch - 78ms/step
# Epoch 391/500
# 104/104 - 8s - loss: 0.0243 - 8s/epoch - 78ms/step
# Epoch 392/500
# 104/104 - 8s - loss: 0.0241 - 8s/epoch - 79ms/step
# Epoch 393/500
# 104/104 - 8s - loss: 0.0222 - 8s/epoch - 77ms/step
# Epoch 394/500
# 104/104 - 8s - loss: 0.0241 - 8s/epoch - 77ms/step
# Epoch 395/500
# 104/104 - 8s - loss: 0.0254 - 8s/epoch - 78ms/step
# Epoch 396/500
# 104/104 - 8s - loss: 0.0229 - 8s/epoch - 78ms/step
# Epoch 397/500
# 104/104 - 8s - loss: 0.0236 - 8s/epoch - 77ms/step
# Epoch 398/500
# 104/104 - 8s - loss: 0.0250 - 8s/epoch - 76ms/step
# Epoch 399/500
# 104/104 - 8s - loss: 0.0223 - 8s/epoch - 77ms/step
# Epoch 400/500
# 104/104 - 8s - loss: 0.0232 - 8s/epoch - 75ms/step
# Epoch 401/500
# 104/104 - 8s - loss: 0.0235 - 8s/epoch - 78ms/step
# Epoch 402/500
# 104/104 - 8s - loss: 0.0246 - 8s/epoch - 77ms/step
# Epoch 403/500
# 104/104 - 8s - loss: 0.0234 - 8s/epoch - 77ms/step
# Epoch 404/500
# 104/104 - 8s - loss: 0.0225 - 8s/epoch - 76ms/step
# Epoch 405/500
# 104/104 - 8s - loss: 0.0229 - 8s/epoch - 78ms/step
# Epoch 406/500
# 104/104 - 8s - loss: 0.0246 - 8s/epoch - 76ms/step
# Epoch 407/500
# 104/104 - 8s - loss: 0.0240 - 8s/epoch - 77ms/step
# Epoch 408/500
# 104/104 - 8s - loss: 0.0233 - 8s/epoch - 78ms/step
# Epoch 409/500
# 104/104 - 8s - loss: 0.0222 - 8s/epoch - 80ms/step
# Epoch 410/500
# 104/104 - 8s - loss: 0.0247 - 8s/epoch - 78ms/step
# Epoch 411/500
# 104/104 - 8s - loss: 0.0236 - 8s/epoch - 79ms/step
# Epoch 412/500
# 104/104 - 8s - loss: 0.0237 - 8s/epoch - 79ms/step
# Epoch 413/500
# 104/104 - 8s - loss: 0.0217 - 8s/epoch - 78ms/step
# Epoch 414/500
# 104/104 - 8s - loss: 0.0239 - 8s/epoch - 81ms/step
# Epoch 415/500
# 104/104 - 8s - loss: 0.0241 - 8s/epoch - 80ms/step
# Epoch 416/500
# 104/104 - 8s - loss: 0.0240 - 8s/epoch - 77ms/step
# Epoch 417/500
# 104/104 - 8s - loss: 0.0249 - 8s/epoch - 78ms/step
# Epoch 418/500
# 104/104 - 8s - loss: 0.0218 - 8s/epoch - 76ms/step
# Epoch 419/500
# 104/104 - 8s - loss: 0.0200 - 8s/epoch - 75ms/step
# Epoch 420/500
# 104/104 - 8s - loss: 0.0228 - 8s/epoch - 76ms/step
# Epoch 421/500
# 104/104 - 8s - loss: 0.0232 - 8s/epoch - 75ms/step
# Epoch 422/500
# 104/104 - 8s - loss: 0.0244 - 8s/epoch - 74ms/step
# Epoch 423/500
# 104/104 - 8s - loss: 0.0228 - 8s/epoch - 78ms/step
# Epoch 424/500
# 104/104 - 8s - loss: 0.0228 - 8s/epoch - 77ms/step
# Epoch 425/500
# 104/104 - 8s - loss: 0.0234 - 8s/epoch - 75ms/step
# Epoch 426/500
# 104/104 - 8s - loss: 0.0229 - 8s/epoch - 75ms/step
# Epoch 427/500
# 104/104 - 8s - loss: 0.0274 - 8s/epoch - 74ms/step
# Epoch 428/500
# 104/104 - 8s - loss: 0.0250 - 8s/epoch - 76ms/step
# Epoch 429/500
# 104/104 - 8s - loss: 0.0224 - 8s/epoch - 77ms/step
# Epoch 430/500
# 104/104 - 8s - loss: 0.0202 - 8s/epoch - 76ms/step
# Epoch 431/500
# 104/104 - 8s - loss: 0.0225 - 8s/epoch - 74ms/step
# Epoch 432/500
# 104/104 - 8s - loss: 0.0246 - 8s/epoch - 76ms/step
# Epoch 433/500
# 104/104 - 8s - loss: 0.0211 - 8s/epoch - 79ms/step
# Epoch 434/500
# 104/104 - 8s - loss: 0.0247 - 8s/epoch - 76ms/step
# Epoch 435/500
# 104/104 - 8s - loss: 0.0250 - 8s/epoch - 76ms/step
# Epoch 436/500
# 104/104 - 8s - loss: 0.0214 - 8s/epoch - 76ms/step
# Epoch 437/500
# 104/104 - 8s - loss: 0.0219 - 8s/epoch - 76ms/step
# Epoch 438/500
# 104/104 - 8s - loss: 0.0209 - 8s/epoch - 76ms/step
# Epoch 439/500
# 104/104 - 8s - loss: 0.0212 - 8s/epoch - 73ms/step
# Epoch 440/500
# 104/104 - 8s - loss: 0.0213 - 8s/epoch - 75ms/step
# Epoch 441/500
# 104/104 - 8s - loss: 0.0219 - 8s/epoch - 75ms/step
# Epoch 442/500
# 104/104 - 8s - loss: 0.0214 - 8s/epoch - 75ms/step
# Epoch 443/500
# 104/104 - 8s - loss: 0.0231 - 8s/epoch - 75ms/step
# Epoch 444/500
# 104/104 - 8s - loss: 0.0211 - 8s/epoch - 74ms/step
# Epoch 445/500
# 104/104 - 8s - loss: 0.0211 - 8s/epoch - 76ms/step
# Epoch 446/500
# 104/104 - 8s - loss: 0.0225 - 8s/epoch - 76ms/step
# Epoch 447/500
# 104/104 - 8s - loss: 0.0199 - 8s/epoch - 74ms/step
# Epoch 448/500
# 104/104 - 8s - loss: 0.0218 - 8s/epoch - 75ms/step
# Epoch 449/500
# 104/104 - 8s - loss: 0.0222 - 8s/epoch - 78ms/step
# Epoch 450/500
# 104/104 - 8s - loss: 0.0215 - 8s/epoch - 75ms/step
# Epoch 451/500
# 104/104 - 8s - loss: 0.0220 - 8s/epoch - 76ms/step
# Epoch 452/500
# 104/104 - 9s - loss: 0.0218 - 9s/epoch - 83ms/step
# Epoch 453/500
# 104/104 - 8s - loss: 0.0210 - 8s/epoch - 79ms/step
# Epoch 454/500
# 104/104 - 8s - loss: 0.0217 - 8s/epoch - 81ms/step
# Epoch 455/500
# 104/104 - 8s - loss: 0.0207 - 8s/epoch - 80ms/step
# Epoch 456/500
# 104/104 - 9s - loss: 0.0210 - 9s/epoch - 83ms/step
# Epoch 457/500
# 104/104 - 8s - loss: 0.0217 - 8s/epoch - 81ms/step
# Epoch 458/500
# 104/104 - 8s - loss: 0.0219 - 8s/epoch - 80ms/step
# Epoch 459/500
# 104/104 - 8s - loss: 0.0219 - 8s/epoch - 77ms/step
# Epoch 460/500
# 104/104 - 8s - loss: 0.0216 - 8s/epoch - 76ms/step
# Epoch 461/500
# 104/104 - 8s - loss: 0.0214 - 8s/epoch - 78ms/step
# Epoch 462/500
# 104/104 - 8s - loss: 0.0212 - 8s/epoch - 78ms/step
# Epoch 463/500
# 104/104 - 8s - loss: 0.0197 - 8s/epoch - 76ms/step
# Epoch 464/500
# 104/104 - 8s - loss: 0.0225 - 8s/epoch - 77ms/step
# Epoch 465/500
# 104/104 - 8s - loss: 0.0211 - 8s/epoch - 76ms/step
# Epoch 466/500
# 104/104 - 8s - loss: 0.0238 - 8s/epoch - 79ms/step
# Epoch 467/500
# 104/104 - 8s - loss: 0.0219 - 8s/epoch - 78ms/step
# Epoch 468/500
# 104/104 - 8s - loss: 0.0208 - 8s/epoch - 77ms/step
# Epoch 469/500
# 104/104 - 8s - loss: 0.0208 - 8s/epoch - 78ms/step
# Epoch 470/500
# 104/104 - 8s - loss: 0.0203 - 8s/epoch - 79ms/step
# Epoch 471/500
# 104/104 - 8s - loss: 0.0243 - 8s/epoch - 81ms/step
# Epoch 472/500
# 104/104 - 8s - loss: 0.0214 - 8s/epoch - 78ms/step
# Epoch 473/500
# 104/104 - 8s - loss: 0.0201 - 8s/epoch - 79ms/step
# Epoch 474/500
# 104/104 - 9s - loss: 0.0241 - 9s/epoch - 82ms/step
# Epoch 475/500
# 104/104 - 8s - loss: 0.0230 - 8s/epoch - 82ms/step
# Epoch 476/500
# 104/104 - 8s - loss: 0.0219 - 8s/epoch - 79ms/step
# Epoch 477/500
# 104/104 - 8s - loss: 0.0226 - 8s/epoch - 80ms/step
# Epoch 478/500
# 104/104 - 8s - loss: 0.0210 - 8s/epoch - 80ms/step
# Epoch 479/500
# 104/104 - 8s - loss: 0.0226 - 8s/epoch - 77ms/step
# Epoch 480/500
# 104/104 - 8s - loss: 0.0208 - 8s/epoch - 77ms/step
# Epoch 481/500
# 104/104 - 8s - loss: 0.0213 - 8s/epoch - 77ms/step
# Epoch 482/500
# 104/104 - 8s - loss: 0.0214 - 8s/epoch - 79ms/step
# Epoch 483/500
# 104/104 - 8s - loss: 0.0200 - 8s/epoch - 78ms/step
# Epoch 484/500
# 104/104 - 8s - loss: 0.0207 - 8s/epoch - 79ms/step
# Epoch 485/500
# 104/104 - 8s - loss: 0.0195 - 8s/epoch - 81ms/step
# Epoch 486/500
# 104/104 - 8s - loss: 0.0199 - 8s/epoch - 80ms/step
# Epoch 487/500
# 104/104 - 8s - loss: 0.0211 - 8s/epoch - 79ms/step
# Epoch 488/500
# 104/104 - 8s - loss: 0.0202 - 8s/epoch - 79ms/step
# Epoch 489/500
# 104/104 - 8s - loss: 0.0213 - 8s/epoch - 80ms/step
# Epoch 490/500
# 104/104 - 8s - loss: 0.0217 - 8s/epoch - 79ms/step
# Epoch 491/500
# 104/104 - 8s - loss: 0.0203 - 8s/epoch - 78ms/step
# Epoch 492/500
# 104/104 - 8s - loss: 0.0187 - 8s/epoch - 78ms/step
# Epoch 493/500
# 104/104 - 8s - loss: 0.0186 - 8s/epoch - 79ms/step
# Epoch 494/500
# 104/104 - 8s - loss: 0.0202 - 8s/epoch - 77ms/step
# Epoch 495/500
# 104/104 - 8s - loss: 0.0203 - 8s/epoch - 80ms/step
# Epoch 496/500
# 104/104 - 8s - loss: 0.0205 - 8s/epoch - 78ms/step
# Epoch 497/500
# 104/104 - 8s - loss: 0.0196 - 8s/epoch - 79ms/step
# Epoch 498/500
# Epoch 499/500
# 104/104 - 8s - loss: 0.0207 - 8s/epoch - 78ms/step
# Epoch 500/500
# 104/104 - 8s - loss: 0.0203 - 8s/epoch - 78ms/step

# %% [markdown]
# #Model Evaluation

# %%
plt.figure(figsize=(15,8), dpi=100)
plt.plot(history.history['loss'], label='Training loss')
plt.title('Mean Absolute Error Loss Plot')
plt.xlabel("Epochs")
plt.ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')

# %% [markdown]
# #Week Evaluation

# %%
#Days to forecast
n_past = 7
#Prediction Dates
predict_period_dates = pd.date_range(list(Dates)[-n_past], periods=n_past, freq='1d').tolist()

#Model Prediction
prediction = model.predict(X_train[-n_past:])
#Inverse Scaling Operation
prediction_copies = np.repeat(prediction, df_train.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())

#Create Dataframe of the Forecasted values    
df_forecast = pd.DataFrame({'Date':np.array(forecast_dates), 'No_calls_Offered':y_pred_future})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])

# %%
#Plotting Last week Forecasting Result
a=14
sns.set_theme()
plt.figure(figsize=(15, 8), dpi=100)
plt.fill_between(x=df_forecast['Date'][:a],
                 y1=df_forecast['No_calls_Offered'][:a]+150,
                 y2=df_forecast['No_calls_Offered'][:a]-140,
                 alpha=0.3
                 )
plt.plot(df['Date'][len(df)-a:], df['No_calls_Offered'][len(df)-a:]);
plt.plot(df_forecast['Date'][:a], df_forecast['No_calls_Offered'][:a]);
plt.xlabel("Days")
plt.ylabel("Calls Volume")
plt.title('One Week Forecasting')
plt.grid(True)
plt.legend(["Real", "Forecasted"]);

# %% [markdown]
# ##Mean Average Percentage Error (MAPE) Score

# %%
Original = df['No_calls_Offered'][len(df)-n_past:].to_numpy()
Forecasted = df_forecast['No_calls_Offered'][:n_past].to_numpy()
MAPE = (1/92)*sum(abs(Original-Forecasted)/abs(Original))*100

print("The Mean Average Percentage Error (MAPE) Score of the model is: ", MAPE)
# Out:
# The Mean Average Percentage Error (MAPE) Score of the model is:  0.12480598845030495

# %% [markdown]
# #Month Evaluation

# %%
#Days to forecast
n_past = 92
#Prediction Dates
predict_period_dates = pd.date_range(list(Dates)[-n_past], periods=n_past, freq='1d').tolist()

#Model Prediction
prediction = model.predict(X_train[-n_past:])
#Inverse Scaling Operation
prediction_copies = np.repeat(prediction, df_train.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())

#Create Dataframe of the Forecasted values    
df_forecast = pd.DataFrame({'Date':np.array(forecast_dates), 'No_calls_Offered':y_pred_future})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])

#Plotting Last week Forecasting Result
a=92
sns.set_theme()
plt.figure(figsize=(15, 8), dpi=100)
plt.plot(df['Date'][len(df)-a:], df['No_calls_Offered'][len(df)-a:]);
plt.plot(df_forecast['Date'][:a], df_forecast['No_calls_Offered'][:a]);
plt.xlabel("Days")
plt.ylabel("Calls Volume")
plt.title('3 Months Forecasting')
plt.grid(True)
plt.legend(["Real", "Forecasted"]);

Original = df['No_calls_Offered'][len(df)-n_past:].to_numpy()
Forecasted = df_forecast['No_calls_Offered'][:n_past].to_numpy()
MAPE = (1/92)*sum(abs(Original-Forecasted)/abs(Original))*100

print("The Mean Average Percentage Error (MAPE) Score of the model is: ", MAPE)
# Out:
# The Mean Average Percentage Error (MAPE) Score of the model is:  2.333377391957227

# %% [markdown]
# #Future Prediction

# %%
#Get last window of features
temp = X_train[0,:,:]
#Variable to store forecasted values
forecast = []

#Loop over future 3 months
for i in range(92):
  #Model Prediction
  pred = model.predict(np.expand_dims(temp, axis=0))
  #Append values
  forecast.append(pred)
  #Delete previous data sample and get new one
  temp = np.delete(temp,0, axis=0)
  temp = np.append(temp, [f_factors[0]], axis=0)
  temp[len(temp)-1,0]=pred

#Rescaling the forecasted values
prediction_temp = np.repeat(np.array(forecast)[:,0], df_train.shape[1], axis=-1)
future_pred = scaler.inverse_transform(prediction_temp)[:,0]

# %% [markdown]
# #Week Prediction

# %%
year = [2021, 2021, 2021, 2021, 2021, 2021, 2021]
month = [8, 8, 8, 8, 8, 8, 8]
day = [1, 2, 3, 4, 5, 6, 7]
data = {'year':year, 'month':month, 'day':day}
week_prediction = pd.DataFrame(data = pd.to_datetime( pd.DataFrame(data=data) ), columns = ['Date'])
week_prediction['No_calls_Offered_predicted'] = future_pred[:7]
week_prediction.to_csv("Week_Prediction.csv")

# %% [markdown]
# #Month Prediction

# %%
month_prediction = pd.DataFrame(data = ['Aug-2021', 'Sept-2021', 'Oct-2021'], columns=['Date'])
month_prediction['No_calls_Offered_predicted'] = [sum(future_pred[:31]),
sum(future_pred[31:61]),
sum(future_pred[61:92])]
#Save Prediction to CSV
month_prediction.to_csv("Month_Prediction.csv")
