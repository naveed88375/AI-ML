# %% [markdown]
# #Install Required Packages

# %%
# %%capture
# !pip install Deep-Fake-Detection
# !pip3 install imageio==2.4.1
# !pip install imageio-ffmpeg

# %% [markdown]
# #Import Packages

# %%
# %%capture
from deepfake_detection import DeepFake_Utils
from moviepy.editor import *

# %% [markdown]
# #Import Inference Video

# %%
InputVideoPath = "FaceForensics++.mp4"
OutputVideoPath = "output.mp4"

# %% [markdown]
# #Perform Inference

# %%
DeepFake_Utils.Inference_on_video(OutputVideoPath,InputVideoPath)
# Out:
# elapsedTime: 9.37  Second
# The Video is FAKE

# %%
VideoFileClip(OutputVideoPath, audio=False, target_resolution=(300,None)).ipython_display()
# Out:
# 100%|█████████▉| 396/397 [00:02<00:00, 163.10it/s]
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
