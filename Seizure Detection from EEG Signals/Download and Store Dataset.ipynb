# %% [markdown]
# #Install Required Packages

# %%
# %%capture
#Install webget into colab
# !pip install wget
#Package to read edf files
# !pip install pyedflib

# %% [markdown]
# #Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# #Import Packages

# %%
#Import required packages
from wget import download
from os import chdir, getcwd, mkdir, path, listdir
import numpy as np
import pandas as pd
from pathlib import Path
from pyedflib import EdfReader
from tqdm.notebook import tqdm

# %% [markdown]
# #Download Dataset

# %%
#Total 24 patients
folders = 24
dataset_path = 'CHB-MIT'
#Dataset URL
base_url = 'https://archive.physionet.org/pn6/chbmit/'

#Empty list to store folder names
list_of_folders = []

#Labeling folders with names
for i in range (1, folders+1):
    if i<10:
        name = 'chb0'
    else:
        name = 'chb'
    list_of_folders.append(name + str(i))

#This function helps in finding files
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start + len(needle))
        n -= 1
    return start

#Get current working directory
initial_path = getcwd()

#Create main dataset folder
if not path.exists(dataset_path):
    mkdir(dataset_path)

#Change directory to the created folder  
chdir(dataset_path)

#List to store files names
files = []

#Iterate over each folder
for l in list_of_folders:
  
    #Create sub-folder if does not exist already
    if not path.exists(l):
        mkdir(l)
        print('Directory', l, 'Created')
    else:
        print ('Directory', l,  'Exists')

    #Change directory to the folder
    chdir(l)
    
    #Get MD5 file for each patient
    folder_url = base_url + l 
    url = folder_url + '/' + 'MD5SUMS'
    print ('Downloading ', url, 'to ', getcwd())
    if not path.isfile('MD5SUMS'):
        download(url)
    else:
        print('File MD5SUMS already exists to ', getcwd())
    #Read sub-file names    
    f = open('MD5SUMS','r')
    lines = f.readlines()
    f.close()

    #Iterate over each file
    for line in lines:
        fname = line[line.find('chb'):line.find('\n')].strip()
        url = folder_url + '/' + fname
        
        #Download each file
        if not path.isfile(fname) and fname.endswith('.seizures'):
            print ('Downloading ', url[:find_nth(url, '.seizures', 1)], 'to ', getcwd())
            download(url[:find_nth(url, '.seizures', 1)])
            print ('Downloading ', url, 'to ', getcwd())
            download(url)
        
    chdir('..')
chdir(initial_path)
# Out:
# Directory chb01 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/MD5SUMS to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_03.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_03.edf.seizures to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_04.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_04.edf.seizures to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_15.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_15.edf.seizures to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_16.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_16.edf.seizures to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_18.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_18.edf.seizures to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_21.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_21.edf.seizures to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_26.edf to  /content/CHB-MIT/chb01
# Downloading  https://archive.physionet.org/pn6/chbmit/chb01/chb01_26.edf.seizures to  /content/CHB-MIT/chb01
# Directory chb02 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/MD5SUMS to  /content/CHB-MIT/chb02
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/chb02_16.edf to  /content/CHB-MIT/chb02
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/chb02_16.edf.seizures to  /content/CHB-MIT/chb02
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/chb02_16+.edf to  /content/CHB-MIT/chb02
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/chb02_16+.edf.seizures to  /content/CHB-MIT/chb02
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/chb02_19.edf to  /content/CHB-MIT/chb02
# Downloading  https://archive.physionet.org/pn6/chbmit/chb02/chb02_19.edf.seizures to  /content/CHB-MIT/chb02
# Directory chb03 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/MD5SUMS to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_01.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_01.edf.seizures to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_02.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_02.edf.seizures to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_03.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_03.edf.seizures to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_04.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_04.edf.seizures to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_34.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_34.edf.seizures to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_35.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_35.edf.seizures to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_36.edf to  /content/CHB-MIT/chb03
# Downloading  https://archive.physionet.org/pn6/chbmit/chb03/chb03_36.edf.seizures to  /content/CHB-MIT/chb03
# Directory chb04 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/MD5SUMS to  /content/CHB-MIT/chb04
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/chb04_05.edf to  /content/CHB-MIT/chb04
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/chb04_05.edf.seizures to  /content/CHB-MIT/chb04
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/chb04_08.edf to  /content/CHB-MIT/chb04
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/chb04_08.edf.seizures to  /content/CHB-MIT/chb04
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/chb04_28.edf to  /content/CHB-MIT/chb04
# Downloading  https://archive.physionet.org/pn6/chbmit/chb04/chb04_28.edf.seizures to  /content/CHB-MIT/chb04
# Directory chb05 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/MD5SUMS to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_06.edf to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_06.edf.seizures to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_13.edf to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_13.edf.seizures to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_16.edf to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_16.edf.seizures to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_17.edf to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_17.edf.seizures to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_22.edf to  /content/CHB-MIT/chb05
# Downloading  https://archive.physionet.org/pn6/chbmit/chb05/chb05_22.edf.seizures to  /content/CHB-MIT/chb05
# Directory chb06 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/MD5SUMS to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_01.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_01.edf.seizures to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_04.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_04.edf.seizures to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_09.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_09.edf.seizures to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_10.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_10.edf.seizures to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_13.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_13.edf.seizures to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_18.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_18.edf.seizures to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_24.edf to  /content/CHB-MIT/chb06
# Downloading  https://archive.physionet.org/pn6/chbmit/chb06/chb06_24.edf.seizures to  /content/CHB-MIT/chb06
# Directory chb07 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/MD5SUMS to  /content/CHB-MIT/chb07
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/chb07_12.edf to  /content/CHB-MIT/chb07
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/chb07_12.edf.seizures to  /content/CHB-MIT/chb07
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/chb07_13.edf to  /content/CHB-MIT/chb07
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/chb07_13.edf.seizures to  /content/CHB-MIT/chb07
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/chb07_19.edf to  /content/CHB-MIT/chb07
# Downloading  https://archive.physionet.org/pn6/chbmit/chb07/chb07_19.edf.seizures to  /content/CHB-MIT/chb07
# Directory chb08 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/MD5SUMS to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_02.edf to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_02.edf.seizures to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_05.edf to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_05.edf.seizures to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_11.edf to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_11.edf.seizures to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_13.edf to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_13.edf.seizures to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_21.edf to  /content/CHB-MIT/chb08
# Downloading  https://archive.physionet.org/pn6/chbmit/chb08/chb08_21.edf.seizures to  /content/CHB-MIT/chb08
# Directory chb09 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/MD5SUMS to  /content/CHB-MIT/chb09
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/chb09_06.edf to  /content/CHB-MIT/chb09
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/chb09_06.edf.seizures to  /content/CHB-MIT/chb09
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/chb09_08.edf to  /content/CHB-MIT/chb09
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/chb09_08.edf.seizures to  /content/CHB-MIT/chb09
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/chb09_19.edf to  /content/CHB-MIT/chb09
# Downloading  https://archive.physionet.org/pn6/chbmit/chb09/chb09_19.edf.seizures to  /content/CHB-MIT/chb09
# Directory chb10 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/MD5SUMS to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_12.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_12.edf.seizures to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_20.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_20.edf.seizures to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_27.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_27.edf.seizures to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_30.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_30.edf.seizures to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_31.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_31.edf.seizures to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_38.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_38.edf.seizures to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_89.edf to  /content/CHB-MIT/chb10
# Downloading  https://archive.physionet.org/pn6/chbmit/chb10/chb10_89.edf.seizures to  /content/CHB-MIT/chb10
# Directory chb11 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/MD5SUMS to  /content/CHB-MIT/chb11
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/chb11_82.edf to  /content/CHB-MIT/chb11
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/chb11_82.edf.seizures to  /content/CHB-MIT/chb11
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/chb11_92.edf to  /content/CHB-MIT/chb11
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/chb11_92.edf.seizures to  /content/CHB-MIT/chb11
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/chb11_99.edf to  /content/CHB-MIT/chb11
# Downloading  https://archive.physionet.org/pn6/chbmit/chb11/chb11_99.edf.seizures to  /content/CHB-MIT/chb11
# Directory chb12 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/MD5SUMS to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_06.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_06.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_08.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_08.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_09.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_09.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_10.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_10.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_11.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_11.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_23.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_23.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_27.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_27.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_28.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_28.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_29.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_29.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_33.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_33.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_36.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_36.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_38.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_38.edf.seizures to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_42.edf to  /content/CHB-MIT/chb12
# Downloading  https://archive.physionet.org/pn6/chbmit/chb12/chb12_42.edf.seizures to  /content/CHB-MIT/chb12
# Directory chb13 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/MD5SUMS to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_19.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_19.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_21.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_21.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_40.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_40.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_55.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_55.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_58.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_58.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_59.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_59.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_60.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_60.edf.seizures to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_62.edf to  /content/CHB-MIT/chb13
# Downloading  https://archive.physionet.org/pn6/chbmit/chb13/chb13_62.edf.seizures to  /content/CHB-MIT/chb13
# Directory chb14 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/MD5SUMS to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_03.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_03.edf.seizures to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_04.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_04.edf.seizures to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_06.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_06.edf.seizures to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_11.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_11.edf.seizures to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_17.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_17.edf.seizures to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_18.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_18.edf.seizures to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_27.edf to  /content/CHB-MIT/chb14
# Downloading  https://archive.physionet.org/pn6/chbmit/chb14/chb14_27.edf.seizures to  /content/CHB-MIT/chb14
# Directory chb15 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/MD5SUMS to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_06.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_06.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_10.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_10.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_15.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_15.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_17.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_17.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_20.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_20.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_22.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_22.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_28.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_28.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_31.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_31.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_40.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_40.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_46.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_46.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_49.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_49.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_52.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_52.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_54.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_54.edf.seizures to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_62.edf to  /content/CHB-MIT/chb15
# Downloading  https://archive.physionet.org/pn6/chbmit/chb15/chb15_62.edf.seizures to  /content/CHB-MIT/chb15
# Directory chb16 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/MD5SUMS to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_10.edf to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_10.edf.seizures to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_11.edf to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_11.edf.seizures to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_14.edf to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_14.edf.seizures to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_16.edf to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_16.edf.seizures to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_17.edf to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_17.edf.seizures to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_18.edf to  /content/CHB-MIT/chb16
# Downloading  https://archive.physionet.org/pn6/chbmit/chb16/chb16_18.edf.seizures to  /content/CHB-MIT/chb16
# Directory chb17 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/MD5SUMS to  /content/CHB-MIT/chb17
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/chb17a_03.edf to  /content/CHB-MIT/chb17
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/chb17a_03.edf.seizures to  /content/CHB-MIT/chb17
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/chb17a_04.edf to  /content/CHB-MIT/chb17
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/chb17a_04.edf.seizures to  /content/CHB-MIT/chb17
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/chb17b_63.edf to  /content/CHB-MIT/chb17
# Downloading  https://archive.physionet.org/pn6/chbmit/chb17/chb17b_63.edf.seizures to  /content/CHB-MIT/chb17
# Directory chb18 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/MD5SUMS to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_29.edf to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_29.edf.seizures to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_30.edf to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_30.edf.seizures to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_31.edf to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_31.edf.seizures to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_32.edf to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_32.edf.seizures to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_35.edf to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_35.edf.seizures to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_36.edf to  /content/CHB-MIT/chb18
# Downloading  https://archive.physionet.org/pn6/chbmit/chb18/chb18_36.edf.seizures to  /content/CHB-MIT/chb18
# Directory chb19 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/MD5SUMS to  /content/CHB-MIT/chb19
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/chb19_28.edf to  /content/CHB-MIT/chb19
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/chb19_28.edf.seizures to  /content/CHB-MIT/chb19
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/chb19_29.edf to  /content/CHB-MIT/chb19
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/chb19_29.edf.seizures to  /content/CHB-MIT/chb19
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/chb19_30.edf to  /content/CHB-MIT/chb19
# Downloading  https://archive.physionet.org/pn6/chbmit/chb19/chb19_30.edf.seizures to  /content/CHB-MIT/chb19
# Directory chb20 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/MD5SUMS to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_12.edf to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_12.edf.seizures to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_13.edf to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_13.edf.seizures to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_14.edf to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_14.edf.seizures to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_15.edf to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_15.edf.seizures to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_16.edf to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_16.edf.seizures to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_68.edf to  /content/CHB-MIT/chb20
# Downloading  https://archive.physionet.org/pn6/chbmit/chb20/chb20_68.edf.seizures to  /content/CHB-MIT/chb20
# Directory chb21 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/MD5SUMS to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_19.edf to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_19.edf.seizures to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_20.edf to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_20.edf.seizures to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_21.edf to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_21.edf.seizures to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_22.edf to  /content/CHB-MIT/chb21
# Downloading  https://archive.physionet.org/pn6/chbmit/chb21/chb21_22.edf.seizures to  /content/CHB-MIT/chb21
# Directory chb22 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/MD5SUMS to  /content/CHB-MIT/chb22
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/chb22_20.edf to  /content/CHB-MIT/chb22
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/chb22_20.edf.seizures to  /content/CHB-MIT/chb22
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/chb22_25.edf to  /content/CHB-MIT/chb22
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/chb22_25.edf.seizures to  /content/CHB-MIT/chb22
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/chb22_38.edf to  /content/CHB-MIT/chb22
# Downloading  https://archive.physionet.org/pn6/chbmit/chb22/chb22_38.edf.seizures to  /content/CHB-MIT/chb22
# Directory chb23 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/MD5SUMS to  /content/CHB-MIT/chb23
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/chb23_06.edf to  /content/CHB-MIT/chb23
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/chb23_06.edf.seizures to  /content/CHB-MIT/chb23
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/chb23_08.edf to  /content/CHB-MIT/chb23
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/chb23_08.edf.seizures to  /content/CHB-MIT/chb23
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/chb23_09.edf to  /content/CHB-MIT/chb23
# Downloading  https://archive.physionet.org/pn6/chbmit/chb23/chb23_09.edf.seizures to  /content/CHB-MIT/chb23
# Directory chb24 Created
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/MD5SUMS to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_01.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_01.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_03.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_03.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_04.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_04.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_06.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_06.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_07.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_07.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_09.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_09.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_11.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_11.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_13.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_13.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_14.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_14.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_15.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_15.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_17.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_17.edf.seizures to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_21.edf to  /content/CHB-MIT/chb24
# Downloading  https://archive.physionet.org/pn6/chbmit/chb24/chb24_21.edf.seizures to  /content/CHB-MIT/chb24

# %% [markdown]
# #Load Dataset

# %%
#Method to read single EDF file
def Edf_Read(file_path, channels):
  #Open file in read mode
  f_read = EdfReader(file_path)
  num_sig = f_read.signals_in_file
  sig_labels = f_read.getSignalLabels()
  sig_labels.append('seizure')
  sigbufs = np.zeros((f_read.getNSamples()[0],num_sig+1))
  #Iterate over number of signals
  for i in np.arange(num_sig): sigbufs[:,i] = f_read.readSignal(i)
  sigbufs[:, num_sig]= 0.0
  #Store the values in data frame
  df =  pd.DataFrame(data = sigbufs, columns = sig_labels)
  df = df.loc[:, channels]
  df = df.loc[:, ~df.columns.duplicated()]
  f_read._close()
  return df.values

#Obtain seizure period from file
def Seizure_Period(f_loc):
  bytes_array = []
  for byte in Path(f_loc).read_bytes(): bytes_array.append(byte)
  return int(str(bin(bytes_array[38]))[2:] + str(bin(bytes_array[41]))[2:],2), bytes_array[49]

#Load paitent data to pandas dataframe
def Load_data (data_dir, Fs, channels):
  #Base data directory
  base_dir = getcwd()
  #Change working directory
  chdir(data_dir)
  #Paitent ids. Not all patients data is considered due to memory issues
  patients = ['chb01','chb04','chb07','chb10','chb13','chb16','chb19']
  #Array to store data
  arr = np.array([], dtype=np.float64).reshape(0, len(channels))
  #Iterate over each patient
  for patient in patients:
      #Change directory to patient
      chdir(patient)
      #Current paitient data
      print('Data reading from patient: ', patient)
      #Gather patient non seizure data
      EDF_Files = [f for f in listdir() if path.isfile(f) and f.endswith('edf')]
      #Arrange the data files
      EDF_Files.sort()
      #Get patient seizure attack fiels
      Seizures_files = [f for f in listdir() if path.isfile(f) and f.endswith('seizures')]
      #Arrange the data
      Seizures_files.sort()
      #Iterate over data files
      for file in tqdm(EDF_Files):
          #Read data from current file
          sigbufs = Edf_Read(file, channels)
          #Check if the file is of seizure attack
          if Seizures_files and Seizures_files[0].startswith(file):
              (start, length) = Seizure_Period(Seizures_files[0])
              for i in range(start * Fs, (start+length)*Fs + 1):
                  sigbufs[i][len(channels)-1] = 1.0
              #Remove the loaded file
              Seizures_files.pop(0)
      #Concatenate the data
      arr = np.concatenate([arr, sigbufs])
      #Change directory
      chdir('..')
  chdir(base_dir)
  #Create a pandas data frame
  df = pd.DataFrame(arr, columns = channels)
  df.reset_index(drop = True, inplace = True)
  return df

# %%
#EEG Channels
channels = ['FP1-F7',
            'F7-T7',
            'T7-P7',
            'P7-O1',
            'FP1-F3',
            'F3-C3',
            'C3-P3',
            'P3-O1',
            'FP2-F4',
            'F4-C4',
            'C4-P4',
            'P4-O2',
            'FP2-F8',
            'F8-T8',
            'T8-P8',
            'P8-O2',
            'FZ-CZ',
            'CZ-PZ',
            'seizure']

#Data folder
Data_dir = 'CHB-MIT'

#Sampling frequency
Fs = 256

#Load the dataset to pandas frame
df = Load_data(Data_dir, Fs, channels)

#Save the frame to a csv file
df.to_csv('data.csv', index = False)

#Move the csv file to gdrive to store
# !mv data.csv /content/gdrive/MyDrive/
# Out:
# Data reading from patient:  chb01
#   0%|          | 0/7 [00:00<?, ?it/s]
# Data reading from patient:  chb04
#   0%|          | 0/3 [00:00<?, ?it/s]
# Data reading from patient:  chb07
#   0%|          | 0/3 [00:00<?, ?it/s]
# Data reading from patient:  chb10
#   0%|          | 0/7 [00:00<?, ?it/s]
# Data reading from patient:  chb13
#   0%|          | 0/8 [00:00<?, ?it/s]
# Data reading from patient:  chb16
#   0%|          | 0/6 [00:00<?, ?it/s]
# Data reading from patient:  chb19
#   0%|          | 0/3 [00:00<?, ?it/s]
